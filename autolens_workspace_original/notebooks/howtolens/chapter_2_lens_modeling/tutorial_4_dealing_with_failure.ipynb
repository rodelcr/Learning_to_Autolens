# %% [markdown]
# Tutorial 4: Dealing With Failure
# ================================
#
# In the previous tutorial we intentionally made our non-linear search infer a local maxima solution and therefore return
# a physically incorrect lens model. In this tutorial, we will pretend that we have modeled our lens and inferred a local
# maxima. We introduce three approaches one can take that changes how we fit the model, all of which have the aim of
# ensuring we infer the global maxima:
#
#  1) Prior Tuning: Tell the non-linear search where to search parameter space.
#  2) Reduce Complexity: Fit a lens model with fewer parameters and therefore a simpler parameter space.
#  3) Look Harder: Brute force a global maxima by telling the non-linear search to sample parameter space more thoroughly.
#
# Each approach has its benefits and disadvantages and we will discuss them in detail.
#
# In the previous tutorial, when we inferred a local maxima we knew that we had done so. For modeling a real lens,
# we do not know the true lens model and it may be unclear if the solution we infered is a global or local maxima. The
# methods we learn in this tutorial are therefore equally important for verifying that a solution that looks like a
# global maxima solution is in indeed the global maxima.

# %%
# %matplotlib inline
from pyprojroot import here
workspace_path = str(here())
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

import numpy as np
from pathlib import Path
import autolens as al
import autolens.plot as aplt
import autofit as af
# Out:
# /Users/rosador/Documents/AGEL/autolens_workspace
# Working Directory has been set to `/Users/rosador/Documents/AGEL/autolens_workspace`
# JAX mode enabled
#
# ***JAX ENABLED***
#
# Using JAX for grad/jit and GPU/TPU acceleration.
# To disable JAX, set: config -> general -> jax -> use_jax = false

# %% [markdown]
# __Initial Setup__
#
# we'll use the same strong lensing data as the previous tutorial, where:
#
#  - The lens galaxy's light is an `Sersic`.
#  - The lens galaxy's total mass distribution is an `Isothermal` and `ExternalShear`.
#  - The source galaxy's light is an `Exponential`.

# %%
dataset_name = "lens_sersic"
dataset_path = Path("dataset") / "imaging" / dataset_name

dataset = al.Imaging.from_fits(
    data_path=dataset_path / "data.fits",
    noise_map_path=dataset_path / "noise_map.fits",
    psf_path=dataset_path / "psf.fits",
    pixel_scales=0.1,
)
# Out:
# 2025-10-24 14:56:51,376 - jax._src.xla_bridge - INFO - Unable to initialize backend 'cuda':
# 2025-10-24 14:56:51,376 - jax._src.xla_bridge - INFO - Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2025-10-24 14:56:51,377 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/autolens/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)

# %% [markdown]
# __Mask__
#
# we'll create and use a smaller 2.6" `Mask2D` again.

# %%
mask_radius = 2.6

mask = al.Mask2D.circular(
    shape_native=dataset.shape_native,
    pixel_scales=dataset.pixel_scales,
    radius=mask_radius,
)

dataset = dataset.apply_mask(mask=mask)
# Out:
# 2025-10-24 14:56:51,684 - autoarray.dataset.imaging.dataset - INFO - Imaging data has been trimmed or padded for FFT convolution.
#   - Original shape : (100, 100)
#   - FFT shape    : (72, 72)
# Padding ensures accurate PSF convolution in Fourier space. Set `disable_fft_pad=True` in Imaging object to turn off automatic padding.
# 2025-10-24 14:56:51,803 - autoarray.dataset.imaging.dataset - INFO - IMAGING - Data masked, contains a total of 2128 image-pixels

# %% [markdown]
# When plotted, the lens light`s is clearly visible in the centre of the image.

# %%
dataset_plotter = aplt.ImagingPlotter(
    dataset=dataset, visuals_2d=aplt.Visuals2D(mask=mask)
)
dataset_plotter.subplot_dataset()

# %% [markdown]
# __Prior Tuning__
#
# First, we will try to assist our non-linear search by tuning our priors. Priors guide the non-linear search on where
# to look in the parameter space. By setting our priors more accurately ('tuning' them), we can help the search find the
# global solution instead of getting stuck at a local maxima.
#
# In a previous tutorial, we learned how to fully customize priors in **PyAutoLens**. Let's apply this knowledge
# now. I've set up a custom search below with priors adjusted to give the non-linear search a better chance of finding
# the global maxima solution. I'll also explain how each prior has been changed from the default values specified in
#  the `config/priors/default` configuration files.
#
# We will call our lens and source galaxies `lens` and `source` this time, for shorter more readable code.
#
# In a previous tutorial, we customized the priors of a model by creating a `Galaxy` as a `Model` and customizing each
# prior:

# %%
lens = af.Model(al.Galaxy, redshift=0.5, mass=al.mp.IsothermalSph)
lens.mass.centre_0 = af.UniformPrior(lower_limit=-0.1, upper_limit=0.1)
lens.mass.centre_1 = af.UniformPrior(lower_limit=-0.1, upper_limit=0.1)

# %% [markdown]
# We can alternatively create the light and mass profiles as a `Model` and customize their parameters, and then pass them
# to the model galaxy and overall model. These two approaches are equivalent, but in this example the style below
# provides more concise and readable code. We will therefore switch to this code style in this tutorial, but may swap
# back and forth between the two styles throughout **HowToLEns** depending on what is more readable.

# %%
bulge = af.Model(al.lp.Sersic)
mass = af.Model(al.mp.Isothermal)

# %% [markdown]
# By default, the prior on the $(y,x)$ coordinates of a `LightProfile` / `MassProfile` is a TruncatedGaussianPrior with
# `mean=0.0` and `sigma=0.3`. However, visual inspection of our strong lens image tells us that its centre (based on the
# lens galaxy's luminous emission) is at x = 0.0" and y = 0.0", so lets reduce the `sigma` value on this prior so the
# non-linear search looks over a very narrow range of `centre` values in parameter space.

# %%
bulge.centre.centre_0 = af.UniformPrior(lower_limit=-0.05, upper_limit=0.05)
bulge.centre.centre_1 = af.UniformPrior(lower_limit=-0.05, upper_limit=0.05)
mass.centre.centre_0 = af.UniformPrior(lower_limit=-0.05, upper_limit=0.05)
mass.centre.centre_1 = af.UniformPrior(lower_limit=-0.05, upper_limit=0.05)

# %% [markdown]
# By default, the elliptical components of the of our lens galaxy's elliptical `LightProfile` are `GaussianPrior`'s
# with `mean=0.0` and `sigma=0.5`. Note that the solution `ell_comps=(0.0, 0.0)` corresponds to a spherical system
# and that all physical solutions (e.g. with axis-ratios running from 0.0 -> 1.0 and position angles 0.0 -> 180.0 degrees)
# are encapsulated for solutions where each component runs from -1.0 -> 1.0).
#
# However, through visual inspection of the image we can often determine the position angle of the lens's light, which
# for this data is clearly 45.0 degrees counter-clockwise from the x-axis. We can update the priors on our elliptical
# components to reflect this. The `lower_limit` and `upper_limit` on a `GaussianPrior` ensure the solutions cannot go
# outside the physically plausible range -1.0 -> 1.0.

# %%
bulge.ell_comps.ell_comps_0 = af.TruncatedGaussianPrior(
    mean=0.333333, sigma=0.1, lower_limit=-1.0, upper_limit=1.0
)
bulge.ell_comps.ell_comps_1 = af.TruncatedGaussianPrior(
    mean=0.0, sigma=0.1, lower_limit=-1.0, upper_limit=1.0
)

# %% [markdown]
# Lets also assume that the ellipticity of the light profile can be used as a prior on that of the mass profile. This may
# not be strictly true (e.g. because of dark matter) so we will use a wider prior, such that the non-linear search can
# change the mass model's ellipticity from that of the light if fitting the data necessitates it.

# %%
mass.ell_comps.ell_comps_0 = af.TruncatedGaussianPrior(
    mean=0.333333, sigma=0.3, lower_limit=-1.0, upper_limit=1.0
)
mass.ell_comps.ell_comps_1 = af.TruncatedGaussianPrior(
    mean=0.0, sigma=0.3, lower_limit=-1.0, upper_limit=1.0
)

# %% [markdown]
# The `effective_radius` of light profile is its 'half-light' radius, the radius at which 50% of its total luminosity
# is internal to a circle defined within that radius. **PyAutoLens** assumes a `UniformPrior` on this quantity between
# 0.0" and 30.0". This large range of values is required to cover the size of all possible strong lenses that can be
# observed in the Universe.
#
# However, inspection of this image shows the lens's light does not extend anywhere near 30.0", so lets reduce it.

# %%
bulge.effective_radius = af.TruncatedGaussianPrior(
    mean=1.0, sigma=0.8, lower_limit=0.0, upper_limit=np.inf
)

# %% [markdown]
# The `sersic_index` defines how concentrated the light profile is. In galaxy structure studies, values of Sersic index
# around 1.0 indicate a disk galaxy, whereas higher values of 3 or 4 indicate an elliptical galaxy. **PyAutoLens**
# assumes a `UniformPrior` between 0.8 and 8.0 by default on this parameter, as a user could model strong lenses
# where the lens is of any morphology.
#
# We often have knowledge of the lens's morphology before we fit it, so in this example we will assume our lens is
# a massive elliptical galaxy with a `sersic_index` near 4.

# %%
bulge.sersic_index = af.TruncatedGaussianPrior(
    mean=4.0, sigma=1.0, lower_limit=0.0, upper_limit=8.
)

# %% [markdown]
# Finally, the `ring` that the lensed source forms clearly has a radius of about 1.6". This is its Einstein radius, so
# lets change the prior from a UniformPrior between 0.0" and 4.0".

# %%
mass.einstein_radius = af.TruncatedGaussianPrior(
    mean=1.6, sigma=0.2, lower_limit=0.0, upper_limit=4.
)

# %% [markdown]
# We now compose the overall model, where the lens galaxy model uses the `Model` components above which had their
# priors customizes.
#
# In this exercise, I'm not going to change any priors on the source galaxy. Whilst lens modeling experts can look at a
# strong lens and often tell you roughly where the source-galaxy is located (in the source-plane), it is something of art
# form. Furthermore, the source's morphology can be pretty complex, making it difficult to come up with a good source
# prior!

# %%
lens = af.Model(
    al.Galaxy, redshift=0.5, bulge=bulge, mass=mass, shear=al.mp.ExternalShear
)

source = af.Model(al.Galaxy, redshift=1.0, bulge=al.lp.ExponentialCore)

model = af.Collection(galaxies=af.Collection(lens=lens, source=source))

# %% [markdown]
# The `info` attribute shows the model in a readable format, including the priors specified above.

# %%
print(model.info)
# Out:
# Total Free Parameters = 20
#
# model                                                                           Collection (N=20)
#     galaxies                                                                    Collection (N=20)
#         lens                                                                    Galaxy (N=14)
#             bulge                                                               Sersic (N=7)
#             mass                                                                Isothermal (N=5)
#             shear                                                               ExternalShear (N=2)
#         source                                                                  Galaxy (N=6)
#             bulge                                                               ExponentialCore (N=6)
#
# galaxies
#     lens
#         redshift                                                                0.5
#         bulge
#             centre
#                 centre_0                                                        UniformPrior [17], lower_limit = -0.05, upper_limit = 0.05
#                 centre_1                                                        UniformPrior [18], lower_limit = -0.05, upper_limit = 0.05
#             ell_comps
#                 ell_comps_0                                                     TruncatedGaussianPrior [21], mean = 0.333333, sigma = 0.1, lower_limit = -1.0, upper_limit = 1.0
#                 ell_comps_1                                                     TruncatedGaussianPrior [22], mean = 0.0, sigma = 0.1, lower_limit = -1.0, upper_limit = 1.0
#             intensity                                                           LogUniformPrior [9], lower_limit = 1e-06, upper_limit = 1000000.0
#             effective_radius                                                    TruncatedGaussianPrior [25], mean = 1.0, sigma = 0.8, lower_limit = 0.0, upper_limit = inf
#             sersic_index                                                        TruncatedGaussianPrior [26], mean = 4.0, sigma = 1.0, lower_limit = 0.0, upper_limit = inf
#         mass
#             centre
#                 centre_0                                                        UniformPrior [19], lower_limit = -0.05, upper_limit = 0.05
#                 centre_1                                                        UniformPrior [20], lower_limit = -0.05, upper_limit = 0.05
#             ell_comps
#                 ell_comps_0                                                     TruncatedGaussianPrior [23], mean = 0.333333, sigma = 0.3, lower_limit = -1.0, upper_limit = 1.0
#                 ell_comps_1                                                     TruncatedGaussianPrior [24], mean = 0.0, sigma = 0.3, lower_limit = -1.0, upper_limit = 1.0
#             einstein_radius                                                     TruncatedGaussianPrior [27], mean = 1.6, sigma = 0.2, lower_limit = 0.0, upper_limit = inf
#         shear
#             gamma_1                                                             UniformPrior [28], lower_limit = -0.2, upper_limit = 0.2
#             gamma_2                                                             UniformPrior [29], lower_limit = -0.2, upper_limit = 0.2
#     source
#         redshift                                                                1.0
#         bulge
#             centre
#                 centre_0                                                        GaussianPrior [30], mean = 0.0, sigma = 0.3
#                 centre_1                                                        GaussianPrior [31], mean = 0.0, sigma = 0.3
#             ell_comps
#                 ell_comps_0                                                     TruncatedGaussianPrior [32], mean = 0.0, sigma = 0.3, lower_limit = -1.0, upper_limit = 1.0
#                 ell_comps_1                                                     TruncatedGaussianPrior [33], mean = 0.0, sigma = 0.3, lower_limit = -1.0, upper_limit = 1.0
#             effective_radius                                                    UniformPrior [34], lower_limit = 0.0, upper_limit = 30.0
#             radius_break                                                        0.025
#             intensity                                                           LogUniformPrior [35], lower_limit = 1e-05, upper_limit = 1000.0
#             gamma                                                               0.25
#             alpha                                                               3.0

# %% [markdown]
# We can now create this custom search and run it. Our non-linear search will now start by sampling higher likelihood
# regions of parameter space, given our improved and more informed priors.

# %%
search = af.Nautilus(
    path_prefix=Path("howtolens") / "chapter_2",
    name="tutorial_4_custom_priors",
    unique_tag=dataset_name,
    n_live=150,
)

analysis = al.AnalysisImaging(dataset=dataset)

# %% [markdown]
# __Run Time__
#
# The run time of the `log_likelihood_function` is around the usual value.
#
# Due to prior tuning, the model-fit should take less than 10000 iterations per free parameter to converge.
#
# Run the non-linear search.

# %%
print(
    "The non-linear search has begun running - checkout the workspace/output/howtolens/chapter_2/tutorial_4_custom_priors"
    " folder for live output of the results, images and lens model."
    " This Jupyter notebook cell with progress once search has completed - this could take some time!"
)

result_custom_priors = search.fit(model=model, analysis=analysis)

print("Search has finished run - you may now continue the notebook.")

print(result_custom_priors.info)
# Out:
# The non-linear search has begun running - checkout the workspace/output/howtolens/chapter_2/tutorial_4_custom_priors folder for live output of the results, images and lens model. This Jupyter notebook cell with progress once search has completed - this could take some time!
# 2025-10-24 14:56:54,869 - autofit.non_linear.search.abstract_search - INFO - Starting non-linear search with 1 cores.
# 2025-10-24 14:56:54,942 - tutorial_4_custom_priors - INFO - The output path of this fit is /Users/rosador/Documents/AGEL/autolens_workspace/output/howtolens/chapter_2/lens_sersic/tutorial_4_custom_priors/67f67f2675d0bd28622e555b17012413
# 2025-10-24 14:56:54,943 - tutorial_4_custom_priors - INFO - Outputting pre-fit files (e.g. model.info, visualization).
# 2025-10-24 14:56:55,549 - tutorial_4_custom_priors - INFO - Starting new Nautilus non-linear search (no previous samples found).
# 2025-10-24 14:56:55,550 - autofit.non_linear.fitness - INFO - JAX: Applying vmap and jit to likelihood function -- may take a few seconds.
# 2025-10-24 14:56:55,550 - autofit.non_linear.fitness - INFO - JAX: vmap and jit applied in 0.0003540515899658203 seconds.
# 2025-10-24 14:56:55,551 - tutorial_4_custom_priors - INFO -
#             Running search where parallelization is disabled.
#
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 29     | 1        | 4        | 10000    | 1.0000 | 1     | -38621.12
# 2025-10-24 14:57:36,054 - tutorial_4_custom_priors - INFO - Fit Running: Updating results after 10000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 57     | 1        | 4        | 19950    | 1.0000 | 1     | -449.62
# 2025-10-24 14:58:14,012 - tutorial_4_custom_priors - INFO - Fit Running: Updating results after 20000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 76     | 1        | 4        | 29900    | 1.0000 | 1     | +2954.27
# 2025-10-24 14:58:51,267 - tutorial_4_custom_priors - INFO - Fit Running: Updating results after 30000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 95     | 1        | 4        | 39850    | 1.0000 | 1     | +3545.55
# 2025-10-24 14:59:32,164 - tutorial_4_custom_priors - INFO - Fit Running: Updating results after 40000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 117    | 1        | 4        | 49800    | 1.0000 | 2     | +3696.11
# 2025-10-24 15:00:20,891 - tutorial_4_custom_priors - INFO - Fit Running: Updating results after 50000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 140    | 1        | 4        | 59750    | 0.0849 | 2975  | +3706.68
# 2025-10-24 15:01:18,245 - tutorial_4_custom_priors - INFO - Fit Running: Updating results after 60000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Finished  | 145    | 1        | 4        | 61600    | N/A    | 3820  | +3706.71
# 2025-10-24 15:01:50,949 - tutorial_4_custom_priors - INFO - Fit Running: Updating results after 70000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Finished  | 145    | 1        | 4        | 61600    | N/A    | 3820  | +3706.71
# 2025-10-24 15:02:15,926 - tutorial_4_custom_priors - INFO - Fit Complete: Updating final results (see output folder).
# 2025-10-24 15:02:40,169 - autofit.non_linear.samples.samples - INFO - Samples with weight less than 1e-10 removed from samples.csv.
# 2025-10-24 15:02:40,502 - autofit.non_linear.search.abstract_search - INFO - Creating latent samples by drawing 100 from the PDF.
# 2025-10-24 15:02:40,505 - autofit.non_linear.analysis.analysis - INFO - JAX: Applying vmap and jit to likelihood function for latent variables -- may take a few seconds.
# 2025-10-24 15:02:40,505 - autofit.non_linear.analysis.analysis - INFO - JAX: vmap and jit applied in 0.00043010711669921875 seconds.
# 2025-10-24 15:03:15,625 - tutorial_4_custom_priors - INFO - Removing search internal folder.
# 2025-10-24 15:03:15,626 - tutorial_4_custom_priors - INFO - Removing all files except for .zip file
# 2025-10-24 15:03:15,979 - tutorial_4_custom_priors - INFO - Search complete, returning result
# Search has finished run - you may now continue the notebook.
# Bayesian Evidence                                                               3706.70836104
# Maximum Log Likelihood                                                          3818.02293820
# Maximum Log Posterior                                                           725269.05334793
#
# model                                                                           Collection (N=20)
#     galaxies                                                                    Collection (N=20)
#         lens                                                                    Galaxy (N=14)
#             bulge                                                               Sersic (N=7)
#             mass                                                                Isothermal (N=5)
#             shear                                                               ExternalShear (N=2)
#         source                                                                  Galaxy (N=6)
#             bulge                                                               ExponentialCore (N=6)
#
# Maximum Log Likelihood Model:
#
# galaxies
#     lens
#         bulge
#             intensity                                                           1.081
#             centre
#                 centre_0                                                        -0.001
#                 centre_1                                                        -0.001
#             ell_comps
#                 ell_comps_0                                                     0.051
#                 ell_comps_1                                                     -0.002
#             effective_radius                                                    0.766
#             sersic_index                                                        3.921
#         mass
#             centre
#                 centre_0                                                        -0.000
#                 centre_1                                                        0.002
#             ell_comps
#                 ell_comps_0                                                     0.052
#                 ell_comps_1                                                     -0.008
#             einstein_radius                                                     1.600
#         shear
#             gamma_1                                                             0.047
#             gamma_2                                                             0.051
#     source
#         bulge
#             centre
#                 centre_0                                                        0.000
#                 centre_1                                                        0.002
#             ell_comps
#                 ell_comps_0                                                     0.087
#                 ell_comps_1                                                     -0.048
#             effective_radius                                                    0.102
#             intensity                                                           4.013
#
#
# Summary (3.0 sigma limits):
#
# galaxies
#     lens
#         bulge
#             intensity                                                           1.0773 (1.0168, 1.1341)
#             centre
#                 centre_0                                                        -0.0006 (-0.0022, 0.0011)
#                 centre_1                                                        -0.0007 (-0.0023, 0.0011)
#             ell_comps
#                 ell_comps_0                                                     0.0513 (0.0454, 0.0565)
#                 ell_comps_1                                                     -0.0022 (-0.0077, 0.0035)
#             effective_radius                                                    0.7677 (0.7472, 0.7907)
#             sersic_index                                                        3.9152 (3.8087, 4.0316)
#         mass
#             centre
#                 centre_0                                                        -0.0009 (-0.0034, 0.0016)
#                 centre_1                                                        0.0017 (-0.0007, 0.0040)
#             ell_comps
#                 ell_comps_0                                                     0.0521 (0.0467, 0.0574)
#                 ell_comps_1                                                     -0.0053 (-0.0117, 0.0011)
#             einstein_radius                                                     1.6003 (1.5984, 1.6022)
#         shear
#             gamma_1                                                             0.0475 (0.0447, 0.0504)
#             gamma_2                                                             0.0501 (0.0470, 0.0534)
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0026, 0.0017)
#                 centre_1                                                        0.0018 (-0.0003, 0.0038)
#             ell_comps
#                 ell_comps_0                                                     0.0909 (0.0705, 0.1099)
#                 ell_comps_1                                                     -0.0490 (-0.0640, -0.0343)
#             effective_radius                                                    0.1014 (0.0983, 0.1047)
#             intensity                                                           4.0025 (3.9066, 4.0956)
#
#
# Summary (1.0 sigma limits):
#
# galaxies
#     lens
#         bulge
#             intensity                                                           1.0773 (1.0569, 1.0976)
#             centre
#                 centre_0                                                        -0.0006 (-0.0011, -0.0000)
#                 centre_1                                                        -0.0007 (-0.0012, -0.0001)
#             ell_comps
#                 ell_comps_0                                                     0.0513 (0.0494, 0.0531)
#                 ell_comps_1                                                     -0.0022 (-0.0040, -0.0004)
#             effective_radius                                                    0.7677 (0.7604, 0.7754)
#             sersic_index                                                        3.9152 (3.8789, 3.9526)
#         mass
#             centre
#                 centre_0                                                        -0.0009 (-0.0018, -0.0001)
#                 centre_1                                                        0.0017 (0.0009, 0.0026)
#             ell_comps
#                 ell_comps_0                                                     0.0521 (0.0504, 0.0539)
#                 ell_comps_1                                                     -0.0053 (-0.0074, -0.0031)
#             einstein_radius                                                     1.6003 (1.5997, 1.6009)
#         shear
#             gamma_1                                                             0.0475 (0.0465, 0.0485)
#             gamma_2                                                             0.0501 (0.0491, 0.0512)
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0012, 0.0002)
#                 centre_1                                                        0.0018 (0.0011, 0.0026)
#             ell_comps
#                 ell_comps_0                                                     0.0909 (0.0842, 0.0973)
#                 ell_comps_1                                                     -0.0490 (-0.0539, -0.0437)
#             effective_radius                                                    0.1014 (0.1003, 0.1025)
#             intensity                                                           4.0025 (3.9725, 4.0334)
#
# instances
#
# galaxies
#     lens
#         redshift                                                                0.5
#     source
#         redshift                                                                1.0
#         bulge
#             radius_break                                                        0.025
#             gamma                                                               0.25
#             alpha                                                               3.0

# %% [markdown]
# __Result__
#
# Bam! We get a good model, which corresponds to the global maxima. By giving our non-linear search a helping hand and
# informing it of where to sample parameter space, we can increase the odds that we find the global maxima solution.

# %%
fit_plotter = aplt.FitImagingPlotter(fit=result_custom_priors.max_log_likelihood_fit)
fit_plotter.subplot_fit()

# %% [markdown]
# __Discussion__
#
# By tuning our priors to the specific lens model we are fitting, we increase the chances of finding the global maxima.
# This approach can also speed up the search, as it spends less time in regions of parameter space that do not
# correspond to good solutions.
#
# Before moving on to the next approach, let’s consider the pros and cons of prior tuning:
#
# **Advantages:**
#
# - Higher likelihood of finding the global maximum log likelihood solutions in parameter space.
#
# - Faster search times, as the non-linear search explores less of the parameter space.
#
# **Disadvantages:**
#
# - Incorrectly specified priors could lead the non-linear search to an incorrect solution.
#
# - It is not always clear how the priors should be tuned, especially for complex lens models.
#
# - Priors tailored to a specific lens need customization for each fit. For large samples of lenses,
# this process would be very time-consuming.
#
# __Approach 2: Reducing Complexity__
#
# The non-linear search may fail because the lens model is too complex, making its parameter space too difficult to
# sample accurately. To address this, we can simplify the lens model while ensuring it remains realistic enough for
# our scientific study. By making certain assumptions, we can reduce the number of model parameters, thereby lowering
# the dimensionality of the parameter space and improving the search's performance.

# %%
bulge = af.Model(al.lp.Sersic)
mass = af.Model(al.mp.Isothermal)

# %% [markdown]
# First, we create a search that assumes that light-traces-mass. That  is, the light profile centre and elliptical
# components are perfectly aligned with the centre and elliptical components of the mass profile. This may, or may
# not, be a reasonable assumption, but it`ll remove 4 parameters from the lens model (the centre and elliptical
# components of the mass profile), so it is worth trying!
#
# To apply our assumption that light traces mass to the model, we `pair` the `centre` and `ell_comps` parameters
# by setting them equal to one another. This removes the  parameter on the left-hand side of the pairing from the lens
# model such that when a model is created it has the same value as the parameter on the right-hand side.

# %%
mass.centre = bulge.centre
mass.ell_comps = bulge.ell_comps

# %% [markdown]
# We now compose the model, which will have a non-linear parameter space with 4 less dimensions than the fit performed
# previously.

# %%
lens = af.Model(
    al.Galaxy, redshift=0.5, bulge=bulge, mass=mass, shear=al.mp.ExternalShear
)

source = af.Model(al.Galaxy, redshift=1.0, bulge=al.lp.ExponentialCore)

model = af.Collection(galaxies=af.Collection(lens=lens, source=source))

# %% [markdown]
# The `info` attribute shows the model in a readable format, including the parameter links specified above.

# %%
print(model.info)
# Out:
# Total Free Parameters = 16
#
# model                                                                           Collection (N=16)
#     galaxies                                                                    Collection (N=16)
#         lens                                                                    Galaxy (N=10)
#             bulge                                                               Sersic (N=7)
#             mass                                                                Isothermal (N=5)
#             shear                                                               ExternalShear (N=2)
#         source                                                                  Galaxy (N=6)
#             bulge                                                               ExponentialCore (N=6)
#
# galaxies
#     lens
#         redshift                                                                0.5
#         bulge - mass
#             centre
#                 centre_0                                                        GaussianPrior [36], mean = 0.0, sigma = 0.3
#                 centre_1                                                        GaussianPrior [37], mean = 0.0, sigma = 0.3
#             ell_comps
#                 ell_comps_0                                                     TruncatedGaussianPrior [38], mean = 0.0, sigma = 0.3, lower_limit = -1.0, upper_limit = 1.0
#                 ell_comps_1                                                     TruncatedGaussianPrior [39], mean = 0.0, sigma = 0.3, lower_limit = -1.0, upper_limit = 1.0
#         bulge
#             intensity                                                           LogUniformPrior [40], lower_limit = 1e-06, upper_limit = 1000000.0
#             effective_radius                                                    UniformPrior [41], lower_limit = 0.0, upper_limit = 30.0
#             sersic_index                                                        UniformPrior [42], lower_limit = 0.8, upper_limit = 5.0
#         mass
#             einstein_radius                                                     UniformPrior [47], lower_limit = 0.0, upper_limit = 8.0
#         shear
#             gamma_1                                                             UniformPrior [48], lower_limit = -0.2, upper_limit = 0.2
#             gamma_2                                                             UniformPrior [49], lower_limit = -0.2, upper_limit = 0.2
#     source
#         redshift                                                                1.0
#         bulge
#             centre
#                 centre_0                                                        GaussianPrior [50], mean = 0.0, sigma = 0.3
#                 centre_1                                                        GaussianPrior [51], mean = 0.0, sigma = 0.3
#             ell_comps
#                 ell_comps_0                                                     TruncatedGaussianPrior [52], mean = 0.0, sigma = 0.3, lower_limit = -1.0, upper_limit = 1.0
#                 ell_comps_1                                                     TruncatedGaussianPrior [53], mean = 0.0, sigma = 0.3, lower_limit = -1.0, upper_limit = 1.0
#             effective_radius                                                    UniformPrior [54], lower_limit = 0.0, upper_limit = 30.0
#             radius_break                                                        0.025
#             intensity                                                           LogUniformPrior [55], lower_limit = 1e-05, upper_limit = 1000.0
#             gamma                                                               0.25
#             alpha                                                               3.0

# %% [markdown]
# We now create this search and run it.

# %%
search = af.Nautilus(
    path_prefix=Path("howtolens") / "chapter_2",
    name="tutorial_4_reducing_complexity",
    unique_tag=dataset_name,
    n_live=200,
)

# %% [markdown]
# __Run Time__
#
# The run time of the `log_likelihood_function` is around the usual value.
#
# Due to the simplest model parameterization, the model-fit should take less than 10000 iterations per free parameter to
# converge.
#
# Run the non-linear search.

# %%
print(
    "The non-linear search has begun running - checkout the workspace/output/howtolens/chapter_2/tutorial_4_reducing_complexity"
    " folder for live output of the results, images and lens model."
    " This Jupyter notebook cell with progress once search has completed - this could take some time!"
)

result_light_trace_mass = search.fit(model=model, analysis=analysis)

print("Search has finished run - you may now continue the notebook.")

print(result_light_trace_mass.info)

fit_plotter = aplt.FitImagingPlotter(fit=result_light_trace_mass.max_log_likelihood_fit)
fit_plotter.subplot_fit()
# Out:
# The non-linear search has begun running - checkout the workspace/output/howtolens/chapter_2/tutorial_4_reducing_complexity folder for live output of the results, images and lens model. This Jupyter notebook cell with progress once search has completed - this could take some time!
# 2025-10-24 15:03:18,783 - autofit.non_linear.search.abstract_search - INFO - Starting non-linear search with 1 cores.
# 2025-10-24 15:03:18,812 - tutorial_4_reducing_complexity - INFO - The output path of this fit is /Users/rosador/Documents/AGEL/autolens_workspace/output/howtolens/chapter_2/lens_sersic/tutorial_4_reducing_complexity/99425a6dbd5ec3c96e602b4b402bb7a4
# 2025-10-24 15:03:18,812 - tutorial_4_reducing_complexity - INFO - Outputting pre-fit files (e.g. model.info, visualization).
# 2025-10-24 15:03:19,292 - tutorial_4_reducing_complexity - INFO - Starting new Nautilus non-linear search (no previous samples found).
# 2025-10-24 15:03:19,292 - autofit.non_linear.fitness - INFO - JAX: Applying vmap and jit to likelihood function -- may take a few seconds.
# 2025-10-24 15:03:19,292 - autofit.non_linear.fitness - INFO - JAX: vmap and jit applied in 0.00038886070251464844 seconds.
# 2025-10-24 15:03:19,293 - tutorial_4_reducing_complexity - INFO -
#             Running search where parallelization is disabled.
#
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 30     | 1        | 4        | 10000    | 1.0000 | 1     | -43243.69
# 2025-10-24 15:03:57,087 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 10000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 61     | 1        | 4        | 20000    | 1.0000 | 1     | -41949.44
# 2025-10-24 15:04:41,144 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 20000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 75     | 1        | 4        | 30000    | 1.0000 | 1     | -36088.22
# 2025-10-24 15:05:21,208 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 30000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 93     | 1        | 4        | 39850    | 1.0000 | 1     | -34729.13
# 2025-10-24 15:06:02,589 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 40000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 106    | 1        | 4        | 49700    | 1.0000 | 1     | -31499.59
# 2025-10-24 15:06:52,144 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 50000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 115    | 1        | 4        | 59550    | 1.0000 | 1     | -28657.14
# 2025-10-24 15:07:47,318 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 60000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 126    | 1        | 4        | 69350    | 1.0000 | 1     | -24179.53
# 2025-10-24 15:08:38,773 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 70000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 143    | 1        | 4        | 79000    | 1.0000 | 1     | -18954.74
# 2025-10-24 15:09:35,208 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 80000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 159    | 1        | 4        | 88550    | 1.0000 | 1     | -16609.43
# 2025-10-24 15:10:33,209 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 90000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 169    | 1        | 4        | 98150    | 1.0000 | 1     | -15684.01
# 2025-10-24 15:11:32,449 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 100000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 181    | 1        | 4        | 107600   | 1.0000 | 1     | -15134.16
# 2025-10-24 15:12:39,322 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 110000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 192    | 1        | 4        | 117200   | 1.0000 | 1     | -14815.23
# 2025-10-24 15:13:49,066 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 120000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 200    | 1        | 4        | 126550   | 1.0000 | 1     | -14654.84
# 2025-10-24 15:15:01,675 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 130000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 211    | 1        | 4        | 135950   | 1.0000 | 3     | -14514.21
# 2025-10-24 15:16:19,920 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 140000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 221    | 1        | 4        | 145300   | 1.0000 | 2     | -14448.47
# 2025-10-24 15:17:45,566 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 150000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 225    | 1        | 4        | 154600   | 1.0000 | 1     | -14402.01
# 2025-10-24 15:19:17,912 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 160000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 232    | 1        | 4        | 163900   | 1.0000 | 3     | -14360.41
# 2025-10-24 15:20:45,117 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 170000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 240    | 1        | 4        | 173150   | 1.0000 | 1     | -14237.47
# 2025-10-24 15:22:18,629 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 180000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 251    | 1        | 4        | 182400   | 1.0000 | 4     | -14036.41
# 2025-10-24 15:23:51,712 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 190000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 259    | 1        | 4        | 191750   | 1.0000 | 1     | -13972.20
# 2025-10-24 15:25:27,650 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 200000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 268    | 1        | 4        | 201150   | 1.0000 | 1     | -13908.74
# 2025-10-24 15:27:08,989 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 210000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 275    | 1        | 4        | 210550   | 1.0000 | 3     | -13862.33
# 2025-10-24 15:28:45,884 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 220000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 279    | 1        | 4        | 219950   | 1.0000 | 1     | -13804.03
# 2025-10-24 15:30:30,127 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 230000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 284    | 2        | 4        | 229350   | 1.0000 | 1     | -13745.87
# 2025-10-24 15:32:23,533 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 240000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 289    | 2        | 4        | 238650   | 1.0000 | 1     | -13675.61
# 2025-10-24 15:34:00,305 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 250000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 294    | 2        | 4        | 247900   | 1.0000 | 2     | -13613.33
# 2025-10-24 15:35:47,644 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 260000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 298    | 2        | 4        | 257100   | 1.0000 | 1     | -13420.70
# 2025-10-24 15:37:43,013 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 270000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 302    | 2        | 4        | 266300   | 1.0000 | 1     | -13347.07
# 2025-10-24 15:39:43,640 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 280000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 305    | 2        | 4        | 275350   | 1.0000 | 1     | -13311.21
# 2025-10-24 15:41:49,506 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 290000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 307    | 3        | 4        | 284200   | 1.0000 | 1     | -13142.91
# 2025-10-24 15:43:54,878 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 300000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 309    | 2        | 4        | 293300   | 1.0000 | 1     | -13119.59
# 2025-10-24 15:46:24,789 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 310000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 310    | 3        | 4        | 302100   | 1.0000 | 1     | -13062.44
# 2025-10-24 15:49:16,658 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 320000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 311    | 2        | 4        | 311200   | 1.0000 | 1     | -13011.27
# 2025-10-24 15:52:22,961 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 330000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 311    | 2        | 4        | 319350   | 1.0000 | 1     | -12924.77
# 2025-10-24 15:55:55,663 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 340000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 313    | 2        | 4        | 328400   | 1.0000 | 1     | -12915.75
# 2025-10-24 16:00:25,345 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 350000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 313    | 2        | 4        | 336250   | 1.0000 | 1     | -12910.10
# 2025-10-24 16:04:48,169 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 360000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 314    | 2        | 4        | 345150   | 1.0000 | 1     | -12874.73
# 2025-10-24 16:09:57,481 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 370000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 314    | 2        | 4        | 353000   | 1.0000 | 1     | -12869.63
# 2025-10-24 16:16:33,921 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 380000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 314    | 2        | 4        | 361900   | 1.0000 | 1     | -12854.51
# 2025-10-24 16:23:40,903 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 390000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 314    | 2        | 4        | 370800   | 1.0000 | 1     | -12816.88
# 2025-10-24 16:30:29,920 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 400000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 314    | 2        | 4        | 379700   | 1.0000 | 1     | -12817.14
# 2025-10-24 16:40:49,018 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 410000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 314    | 2        | 4        | 388600   | 1.0000 | 1     | -12817.34
# 2025-10-24 16:50:26,666 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 420000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 397500   | 1.0000 | 1     | -12815.80
# 2025-10-24 17:01:06,918 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 430000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 400500   | 1.0000 | 1     | -12816.12
# 2025-10-24 17:06:02,661 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 440000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 404050   | 1.0000 | 1     | -12800.46
# 2025-10-24 17:11:05,953 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 450000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 408200   | 1.0000 | 1     | -12800.52
# 2025-10-24 17:16:11,973 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 460000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 413100   | 1.0000 | 1     | -12800.75
# 2025-10-24 17:22:00,546 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 470000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 418800   | 1.0000 | 1     | -12800.97
# 2025-10-24 17:29:47,732 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 480000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 425500   | 1.0000 | 1     | -12801.17
# 2025-10-24 17:39:40,253 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 490000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 433350   | 1.0000 | 1     | -12801.37
# 2025-10-25 08:20:01,213 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 500000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 442250   | 1.0000 | 1     | -12801.52
# 2025-10-25 20:11:47,794 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 510000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 451150   | 1.0000 | 1     | -12801.66
# 2025-10-26 10:11:13,628 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 520000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 460050   | 1.0000 | 1     | -12801.78
# 2025-10-26 23:37:37,020 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 530000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 468950   | 1.0000 | 1     | -12801.89
# 2025-10-27 09:21:31,337 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 540000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 477850   | 1.0000 | 1     | -12801.99
# 2025-10-27 09:40:49,744 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 550000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 486750   | 1.0000 | 1     | -12802.08
# 2025-10-27 09:55:33,128 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 560000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 495650   | 1.0000 | 1     | -12802.17
# 2025-10-27 10:17:40,665 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 570000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 315    | 2        | 4        | 504550   | 1.0000 | 1     | -12802.24
# 2025-10-27 10:35:03,826 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 580000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 316    | 2        | 4        | 513450   | 1.0000 | 1     | -12798.22
# 2025-10-27 10:54:24,217 - tutorial_4_reducing_complexity - INFO - Fit Running: Updating results after 590000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 316    | 2        | 4        | 513450   | 1.0000 | 1     | -12798.22
# 2025-10-27 10:56:15,610 - tutorial_4_reducing_complexity - INFO - Fit Complete: Updating final results (see output folder).
# 2025-10-27 10:58:09,428 - autofit.non_linear.samples.samples - INFO - Samples with weight less than 1e-10 removed from samples.csv.
# 2025-10-27 10:58:09,430 - autofit.non_linear.search.abstract_search - INFO - Creating latent samples by drawing 100 from the PDF.
# 2025-10-27 10:58:09,444 - autofit.non_linear.analysis.analysis - INFO - JAX: Applying vmap and jit to likelihood function for latent variables -- may take a few seconds.
# 2025-10-27 10:58:09,445 - autofit.non_linear.analysis.analysis - INFO - JAX: vmap and jit applied in 0.00046515464782714844 seconds.
# 2025-10-27 11:00:19,329 - tutorial_4_reducing_complexity - INFO - Removing search internal folder.
# 2025-10-27 11:00:19,330 - tutorial_4_reducing_complexity - INFO - Removing all files except for .zip file
# 2025-10-27 11:00:19,537 - tutorial_4_reducing_complexity - INFO - Search complete, returning result
# Search has finished run - you may now continue the notebook.
# Bayesian Evidence                                                               -12798.21772102
# Maximum Log Likelihood                                                          -12656.27067791
# Maximum Log Posterior                                                           771541.44525508
#
# model                                                                           Collection (N=16)
#     galaxies                                                                    Collection (N=16)
#         lens                                                                    Galaxy (N=10)
#             bulge                                                               Sersic (N=7)
#             mass                                                                Isothermal (N=5)
#             shear                                                               ExternalShear (N=2)
#         source                                                                  Galaxy (N=6)
#             bulge                                                               ExponentialCore (N=6)
#
# Maximum Log Likelihood Model:
#
# galaxies
#     lens
#         bulge - mass
#             centre
#                 centre_0                                                        -0.013
#                 centre_1                                                        0.013
#             ell_comps
#                 ell_comps_0                                                     0.081
#                 ell_comps_1                                                     0.003
#         bulge
#             intensity                                                           0.795
#             effective_radius                                                    0.953
#             sersic_index                                                        2.775
#         mass
#             einstein_radius                                                     1.622
#         shear
#             gamma_1                                                             0.043
#             gamma_2                                                             0.058
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.013
#                 centre_1                                                        0.000
#             ell_comps
#                 ell_comps_0                                                     0.018
#                 ell_comps_1                                                     0.046
#             effective_radius                                                    0.182
#             intensity                                                           1.274
#
#
# Summary (3.0 sigma limits):
#
# galaxies
#     lens
#         bulge - mass
#             centre
#                 centre_0                                                        -0.0125 (-0.0125, -0.0125)
#                 centre_1                                                        0.0125 (0.0125, 0.0125)
#             ell_comps
#                 ell_comps_0                                                     0.0808 (0.0808, 0.0810)
#                 ell_comps_1                                                     0.0035 (0.0035, 0.0040)
#         bulge
#             intensity                                                           0.7951 (0.7951, 0.8071)
#             effective_radius                                                    0.9534 (0.9522, 0.9534)
#             sersic_index                                                        2.7755 (2.6795, 2.7755)
#         mass
#             einstein_radius                                                     1.6216 (1.6216, 1.6222)
#         shear
#             gamma_1                                                             0.0430 (0.0430, 0.0436)
#             gamma_2                                                             0.0583 (0.0583, 0.0595)
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.0133 (-0.0137, -0.0133)
#                 centre_1                                                        0.0002 (0.0002, 0.0019)
#             ell_comps
#                 ell_comps_0                                                     0.0176 (0.0176, 0.0355)
#                 ell_comps_1                                                     0.0455 (0.0313, 0.0455)
#             effective_radius                                                    0.1817 (0.1727, 0.1817)
#             intensity                                                           1.2740 (1.2740, 1.3462)
#
#
# Summary (1.0 sigma limits):
#
# galaxies
#     lens
#         bulge - mass
#             centre
#                 centre_0                                                        -0.0125 (-0.0125, -0.0125)
#                 centre_1                                                        0.0125 (0.0125, 0.0125)
#             ell_comps
#                 ell_comps_0                                                     0.0808 (0.0808, 0.0808)
#                 ell_comps_1                                                     0.0035 (0.0035, 0.0035)
#         bulge
#             intensity                                                           0.7951 (0.7951, 0.7951)
#             effective_radius                                                    0.9534 (0.9534, 0.9534)
#             sersic_index                                                        2.7755 (2.7755, 2.7755)
#         mass
#             einstein_radius                                                     1.6216 (1.6216, 1.6216)
#         shear
#             gamma_1                                                             0.0430 (0.0430, 0.0430)
#             gamma_2                                                             0.0583 (0.0583, 0.0583)
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.0133 (-0.0133, -0.0133)
#                 centre_1                                                        0.0002 (0.0002, 0.0002)
#             ell_comps
#                 ell_comps_0                                                     0.0176 (0.0176, 0.0176)
#                 ell_comps_1                                                     0.0455 (0.0455, 0.0455)
#             effective_radius                                                    0.1817 (0.1817, 0.1817)
#             intensity                                                           1.2740 (1.2740, 1.2740)
#
# instances
#
# galaxies
#     lens
#         redshift                                                                0.5
#     source
#         redshift                                                                1.0
#         bulge
#             radius_break                                                        0.025
#             gamma                                                               0.25
#             alpha                                                               3.0

# %% [markdown]
# __Result__
#
# The results look pretty good. Our source galaxy fits the data pretty well and we've clearly inferred a model that
# looks similar to the one above. However, inspection of the residuals shows that the fit was not quite as good as the
# first search.
#
# It turns out that for this simulated lens, light did not perfectly trace mass. The quality of the fit suffered and the
# highest value of log likelihood the search inferred was lower as a result.
#
# Herein lies the pitfalls of making assumptions, they may make your model less realistic and your fits worse!
#
# __Discussion__
#
# Let’s consider the advantages and disadvantages of simplifying the model:
#
# Advantages:
#
# - By reducing the complexity of the parameter space, we increase the chances of finding the global maximum log
# likelihood, and the search requires less time to do so.
#
# - Unlike with tuned priors, this approach is not specific to a single lens, allowing us to use it on many strong lens
# images.
#
# Disadvantages:
#
# - Our model is less realistic, which may negatively impact the accuracy of our fit and the scientific results we
# derive from it.
#
# __Approach 3: Look Harder__
#
# In approaches 1 and 2, we assisted our non-linear search to find the highest log likelihood regions of parameter
# space. In approach 3, we're simply going to tell it to "look harder."
#
# Every non-linear search has settings that control how thoroughly it explores parameter space. One such setting is the
# number of live points used by `Nautilus`. The more thoroughly the search examines the space, the more likely it is to
# find the global maximum lens model. However, this also means the search will take longer!
#
# Below, we configure a more thorough Nautilus search with `n_live=200`. These settings and what they change are
# discussed in the optional tutorial `howtolens/chapter_optional/tutorial_searches.ipynb`.
#
# Due to the long run times of this search, the output is commented out below. Feel free to uncomment it to run the
# script faster.

# %%
lens = af.Model(
    al.Galaxy,
    redshift=0.5,
    bulge=al.lp.Sersic,
    mass=al.mp.Isothermal,
    shear=al.mp.ExternalShear,
)

source = af.Model(al.Galaxy, redshift=1.0, bulge=al.lp.ExponentialCore)

model = af.Collection(galaxies=af.Collection(lens=lens, source=source))

search = af.Nautilus(
    path_prefix=Path("howtolens") / "chapter_2",
    name="tutorial_4_look_harder",
    unique_tag=dataset_name,
    n_live=300,
)
# %%
'''
__Run Time__

The run time of the `log_likelihood_function` is around the usual value. 

Due to the more thorough Nautilus settings, the the model-fit should take more than 10000 iterations per free parameter 
to converge and thus take longer than we are used too.

Run the non-linear search.
'''
# Out:
# '\n__Run Time__\n\nThe run time of the `log_likelihood_function` is around the usual value. \n\nDue to the more thorough Nautilus settings, the the model-fit should take more than 10000 iterations per free parameter \nto converge and thus take longer than we are used too.\n\nRun the non-linear search.\n'

# %%
print(
    "The non-linear search has begun running - checkout the workspace/output/howtolens/chapter_2/tutorial_4_look_harder"
    " folder for live output of the results, images and lens model."
    " This Jupyter notebook cell with progress once search has completed - this could take some time!"
)

result_look_harder = search.fit(model=model, analysis=analysis)

print("Search has finished run - you may now continue the notebook.")

print(result_look_harder.info)

fit_plotter = aplt.FitImagingPlotter(fit=result_look_harder.max_log_likelihood_fit)
fit_plotter.subplot_fit()
# Out:
# The non-linear search has begun running - checkout the workspace/output/howtolens/chapter_2/tutorial_4_look_harder folder for live output of the results, images and lens model. This Jupyter notebook cell with progress once search has completed - this could take some time!
# 2025-10-27 11:00:30,937 - autofit.non_linear.search.abstract_search - INFO - Starting non-linear search with 1 cores.
# 2025-10-27 11:00:30,964 - tutorial_4_look_harder - INFO - The output path of this fit is /Users/rosador/Documents/AGEL/autolens_workspace/output/howtolens/chapter_2/lens_sersic/tutorial_4_look_harder/0ab6235570d8f21d8ec855fdaf38da0f
# 2025-10-27 11:00:30,964 - tutorial_4_look_harder - INFO - Outputting pre-fit files (e.g. model.info, visualization).
# 2025-10-27 11:00:31,481 - tutorial_4_look_harder - INFO - Starting new Nautilus non-linear search (no previous samples found).
# 2025-10-27 11:00:31,481 - autofit.non_linear.fitness - INFO - JAX: Applying vmap and jit to likelihood function -- may take a few seconds.
# 2025-10-27 11:00:31,481 - autofit.non_linear.fitness - INFO - JAX: vmap and jit applied in 0.0003509521484375 seconds.
# 2025-10-27 11:00:31,482 - tutorial_4_look_harder - INFO -
#             Running search where parallelization is disabled.
#
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 20     | 1        | 4        | 10000    | 1.0000 | 1     | -43870.17
# 2025-10-27 11:01:09,019 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 10000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 40     | 1        | 4        | 19800    | 1.0000 | 1     | -40207.73
# 2025-10-27 11:01:49,752 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 20000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 50     | 1        | 4        | 29800    | 1.0000 | 1     | -37511.49
# 2025-10-27 11:02:34,431 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 30000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 57     | 1        | 4        | 39500    | 1.0000 | 1     | -19682.77
# 2025-10-27 11:03:15,627 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 40000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 65     | 1        | 4        | 49250    | 1.0000 | 1     | -6411.53
# 2025-10-27 11:03:59,666 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 50000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 75     | 1        | 4        | 58800    | 1.0000 | 1     | +638.61
# 2025-10-27 11:04:43,324 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 60000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 86     | 1        | 4        | 68550    | 1.0000 | 1     | +2069.25
# 2025-10-27 11:05:30,816 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 70000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 97     | 1        | 4        | 78200    | 1.0000 | 1     | +3083.75
# 2025-10-27 11:06:20,905 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 80000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 108    | 1        | 4        | 87850    | 1.0000 | 1     | +3454.87
# 2025-10-27 11:07:12,706 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 90000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 121    | 1        | 4        | 97550    | 1.0000 | 1     | +3623.56
# 2025-10-27 11:08:11,857 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 100000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 133    | 1        | 4        | 107000   | 1.0000 | 1     | +3683.83
# 2025-10-27 11:09:12,131 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 110000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 147    | 1        | 4        | 116750   | 0.9980 | 2     | +3697.12
# 2025-10-27 11:10:22,605 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 120000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 159    | 1        | 4        | 126250   | 0.1718 | 3295  | +3696.95
# 2025-10-27 11:11:33,097 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 130000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Finished  | 166    | 1        | 4        | 131300   | N/A    | 7629  | +3697.01
# 2025-10-27 11:12:32,400 - tutorial_4_look_harder - INFO - Fit Running: Updating results after 140000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Finished  | 166    | 1        | 4        | 131300   | N/A    | 7629  | +3697.01
# 2025-10-27 11:13:16,606 - tutorial_4_look_harder - INFO - Fit Complete: Updating final results (see output folder).
# 2025-10-27 11:14:00,075 - autofit.non_linear.samples.samples - INFO - Samples with weight less than 1e-10 removed from samples.csv.
# 2025-10-27 11:14:00,799 - autofit.non_linear.search.abstract_search - INFO - Creating latent samples by drawing 100 from the PDF.
# 2025-10-27 11:14:00,803 - autofit.non_linear.analysis.analysis - INFO - JAX: Applying vmap and jit to likelihood function for latent variables -- may take a few seconds.
# 2025-10-27 11:14:00,804 - autofit.non_linear.analysis.analysis - INFO - JAX: vmap and jit applied in 0.0004010200500488281 seconds.
# 2025-10-27 11:14:49,029 - tutorial_4_look_harder - INFO - Removing search internal folder.
# 2025-10-27 11:14:49,031 - tutorial_4_look_harder - INFO - Removing all files except for .zip file
# 2025-10-27 11:14:49,613 - tutorial_4_look_harder - INFO - Search complete, returning result
# Search has finished run - you may now continue the notebook.
# Bayesian Evidence                                                               3697.01199974
# Maximum Log Likelihood                                                          3818.27905755
# Maximum Log Posterior                                                           783600.79856205
#
# model                                                                           Collection (N=20)
#     galaxies                                                                    Collection (N=20)
#         lens                                                                    Galaxy (N=14)
#             bulge                                                               Sersic (N=7)
#             mass                                                                Isothermal (N=5)
#             shear                                                               ExternalShear (N=2)
#         source                                                                  Galaxy (N=6)
#             bulge                                                               ExponentialCore (N=6)
#
# Maximum Log Likelihood Model:
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.000
#                 centre_1                                                        -0.001
#             ell_comps
#                 ell_comps_0                                                     0.052
#                 ell_comps_1                                                     -0.001
#             intensity                                                           1.065
#             effective_radius                                                    0.773
#             sersic_index                                                        3.922
#         mass
#             centre
#                 centre_0                                                        -0.001
#                 centre_1                                                        0.001
#             ell_comps
#                 ell_comps_0                                                     0.052
#                 ell_comps_1                                                     -0.004
#             einstein_radius                                                     1.600
#         shear
#             gamma_1                                                             0.048
#             gamma_2                                                             0.050
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.000
#                 centre_1                                                        0.001
#             ell_comps
#                 ell_comps_0                                                     0.096
#                 ell_comps_1                                                     -0.049
#             effective_radius                                                    0.101
#             intensity                                                           4.018
#
#
# Summary (3.0 sigma limits):
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0022, 0.0011)
#                 centre_1                                                        -0.0007 (-0.0023, 0.0010)
#             ell_comps
#                 ell_comps_0                                                     0.0512 (0.0460, 0.0564)
#                 ell_comps_1                                                     -0.0022 (-0.0078, 0.0033)
#             intensity                                                           1.0779 (1.0180, 1.1365)
#             effective_radius                                                    0.7674 (0.7467, 0.7906)
#             sersic_index                                                        3.9144 (3.8074, 4.0278)
#         mass
#             centre
#                 centre_0                                                        -0.0009 (-0.0033, 0.0016)
#                 centre_1                                                        0.0018 (-0.0006, 0.0041)
#             ell_comps
#                 ell_comps_0                                                     0.0522 (0.0468, 0.0573)
#                 ell_comps_1                                                     -0.0053 (-0.0114, 0.0014)
#             einstein_radius                                                     1.6003 (1.5985, 1.6021)
#         shear
#             gamma_1                                                             0.0475 (0.0447, 0.0506)
#             gamma_2                                                             0.0502 (0.0470, 0.0532)
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0026, 0.0017)
#                 centre_1                                                        0.0019 (-0.0002, 0.0039)
#             ell_comps
#                 ell_comps_0                                                     0.0909 (0.0707, 0.1108)
#                 ell_comps_1                                                     -0.0490 (-0.0642, -0.0337)
#             effective_radius                                                    0.1014 (0.0981, 0.1045)
#             intensity                                                           4.0034 (3.9139, 4.0953)
#
#
# Summary (1.0 sigma limits):
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0011, 0.0000)
#                 centre_1                                                        -0.0007 (-0.0012, -0.0001)
#             ell_comps
#                 ell_comps_0                                                     0.0512 (0.0494, 0.0529)
#                 ell_comps_1                                                     -0.0022 (-0.0041, -0.0003)
#             intensity                                                           1.0779 (1.0578, 1.0981)
#             effective_radius                                                    0.7674 (0.7601, 0.7751)
#             sersic_index                                                        3.9144 (3.8776, 3.9527)
#         mass
#             centre
#                 centre_0                                                        -0.0009 (-0.0018, -0.0001)
#                 centre_1                                                        0.0018 (0.0010, 0.0026)
#             ell_comps
#                 ell_comps_0                                                     0.0522 (0.0503, 0.0539)
#                 ell_comps_1                                                     -0.0053 (-0.0074, -0.0032)
#             einstein_radius                                                     1.6003 (1.5997, 1.6009)
#         shear
#             gamma_1                                                             0.0475 (0.0466, 0.0485)
#             gamma_2                                                             0.0502 (0.0491, 0.0512)
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0012, 0.0002)
#                 centre_1                                                        0.0019 (0.0012, 0.0026)
#             ell_comps
#                 ell_comps_0                                                     0.0909 (0.0844, 0.0976)
#                 ell_comps_1                                                     -0.0490 (-0.0541, -0.0439)
#             effective_radius                                                    0.1014 (0.1003, 0.1025)
#             intensity                                                           4.0034 (3.9728, 4.0336)
#
# instances
#
# galaxies
#     lens
#         redshift                                                                0.5
#     source
#         redshift                                                                1.0
#         bulge
#             radius_break                                                        0.025
#             gamma                                                               0.25
#             alpha                                                               3.0

# %% [markdown]
# Let's list the advantages and disadvantages of simply adjusting the non-linear search:
#
# **Advantages:**
#
# - It’s easy to set up; just change the settings of the non-linear search.
#
# - It generalizes to any strong lens.
#
# - We can retain a more complex lens model.
#
# **Disadvantage:**
#
# - It can be very expensive in terms of time. For very complex models, the run times can extend to hours, days,
# weeks, or even months!
#
# In conclusion, we can now fit strong lenses effectively. When the process fails, we know how to make it work.
# In chapter 3 of **HowToLens**, we will introduce a technique called 'non-linear search chaining', which performs a model
# fit by chaining together multiple searches back-to-back . This allows us to combine the 3 different approaches
# discussed and exploit the advantages of each, whilst not being hindered by their disadvantages.
#
# With search chaining, we can:
#
#  - Fit simpler models with lower dimensionality parameter spaces in the earlier searches and gradually increase the
#   lens model complexity search-by-search, guiding the model-fit to a sufficiently realistic lens model.
#
#  - In these earlier searches (with easier to sample parameter spaces), use fast non-linear search settings to compute
#  the results quickly and switch to slower settings in later searches when we fit more complex lens models.
#
#  - Use 'prior passing' to setup the priors of each parameter in the later searches, based on the lens models inferred
#  by the earlier searches. We can therefore guide each search on how to sample a complex lens model's parameter space
#  in a way that can be fully generalized to any strong lens.
#
# To wrap up chapter 2, we have a few more tutorials, where we will discuss masking in more detail, the `Result` object
# and how to make **PyAutoLens** run faster.
