# %% [markdown]
# Tutorial 3: Realism and Complexity
# ==================================
#
# In the previous two tutorials, we fitted a fairly crude and unrealistic model: the lens's mass was spherical, as was
# the source's light. Given most lens galaxies are literally called 'elliptical galaxies' we should probably model their
# mass as elliptical! Furthermore, we have completely omitted the lens galaxy's light, which in real observations
# outshines the source's light and therefore must be included in the lens model.
#
# In this tutorial, we'll use a more realistic lens model, which consists of the following light and mass profiles:
#
#  - An `Sersic` light profile for the lens galaxy's light [7 parameters].
#  - A `Isothermal` mass profile for the lens galaxy's mass [5 parameters].
#  - An `ExternalShear` which accounts for additional lensing by other galaxies nearby the lens [2 parameters].
#  - An `Exponential` light profile for the source-galaxy's light (this is probably still too simple for most
#  strong lenses, but we will worry about that later) [6 parameters].
#
# This lens model has 20 free parameters, meaning that the parameter space and likelihood function it defines has a
# dimensionality of N=20. This is over double the number of parameters and dimensions of the models we fitted in the
# previous tutorials and in future exercises, we will fit even more complex models with some 30+ parameters.
#
# Therefore, take note, as we make our lens model more realistic, we also make its parameter space more complex, this is
# an important concept to keep in mind for the remainder of this chapter!

# %%
# %matplotlib inline
from pyprojroot import here
workspace_path = str(here())
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

from pathlib import Path
import autolens as al
import autolens.plot as aplt
import autofit as af
# Out:
# /Users/rosador/Documents/AGEL/autolens_workspace
# Working Directory has been set to `/Users/rosador/Documents/AGEL/autolens_workspace`
# JAX mode enabled
#
# ***JAX ENABLED***
#
# Using JAX for grad/jit and GPU/TPU acceleration.
# To disable JAX, set: config -> general -> jax -> use_jax = false

# %% [markdown]
# __Initial Setup__
#
# we'll use new strong lensing data, where:
#
#  - The lens galaxy's light is an `Sersic`.
#  - The lens galaxy's total mass distribution is an `Isothermal` and `ExternalShear`.
#  - The source galaxy's light is an `Exponential`.

# %%
dataset_name = "lens_sersic"
dataset_path = Path("dataset") / "imaging" / dataset_name

dataset = al.Imaging.from_fits(
    data_path=dataset_path / "data.fits",
    noise_map_path=dataset_path / "noise_map.fits",
    psf_path=dataset_path / "psf.fits",
    pixel_scales=0.1,
)
# Out:
# 2025-11-20 14:25:25,163 - jax._src.xla_bridge - INFO - Unable to initialize backend 'cuda':
# 2025-11-20 14:25:25,164 - jax._src.xla_bridge - INFO - Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2025-11-20 14:25:25,164 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/autolens/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)

# %% [markdown]
# __Mask__
#
# We'll create and use a 2.5" `Mask2D`, which is slightly smaller than the masks we used in previous tutorials.

# %%
mask_radius = 2.5

mask = al.Mask2D.circular(
    shape_native=dataset.shape_native,
    pixel_scales=dataset.pixel_scales,
    radius=mask_radius,
)

dataset = dataset.apply_mask(mask=mask)
# Out:
# 2025-11-20 14:25:27,095 - autoarray.dataset.imaging.dataset - INFO - Imaging data has been trimmed or padded for FFT convolution.
#   - Original shape : (100, 100)
#   - FFT shape    : (72, 72)
# Padding ensures accurate PSF convolution in Fourier space. Set `disable_fft_pad=True` in Imaging object to turn off automatic padding.
# 2025-11-20 14:25:27,221 - autoarray.dataset.imaging.dataset - INFO - IMAGING - Data masked, contains a total of 1976 image-pixels

# %% [markdown]
# When plotted, the lens light`s is clearly visible in the centre of the image.

# %%
dataset_plotter = aplt.ImagingPlotter(
    dataset=dataset, visuals_2d=aplt.Visuals2D(mask=mask)
)
dataset_plotter.subplot_dataset()

# %% [markdown]
# __Model__
#
# Now lets fit the dataset using a search.
#
# Below, we write the `model` using the **PyAutoFit** concise API, which means that we do not have to specify that
# each component of the model is a `Model` object. This is because we are passing the light and mass profiles directly
# to the `Collection` object, which assumes they are `Model` objects.
#
# We will use this consistent API throughout the chapter, so you should get used to it!

# %%
model = af.Collection(
    galaxies=af.Collection(
        lens=af.Model(
            al.Galaxy,
            redshift=0.5,
            bulge=al.lp.Sersic,
            mass=al.mp.Isothermal,
            shear=al.mp.ExternalShear,
        ),
        source=af.Model(al.Galaxy, redshift=1.0, bulge=al.lp.ExponentialCore),
    ),
)

# %% [markdown]
# __Search + Analysis__
#
# We set up `Nautilus` as we did in the previous tutorial, however given the increase in model complexity we'll use
# a higher `n_live` value of 150 to ensure we sample the complex parameter space efficiently.

# %%
search = af.Nautilus(
    path_prefix=Path("howtolens") / "chapter_2",
    name="tutorial_3_realism_and_complexity",
    unique_tag=dataset_name,
    n_live=200,
)

analysis = al.AnalysisImaging(dataset=dataset)

# %% [markdown]
# __Run Time__
#
# The run time of the `log_likelihood_function` is a little bit more than previous tutorials, because we added more
# light and mass profiles to the model. It is the increased number of parameters that increases the expected run time
# more.
#
# Run the non-linear search.

# %%
print(
    "The non-linear search has begun running - checkout the autolens_workspace/output/howtolens/chapter_2/tutorial_3_realism_and_complexity"
    " folder for live output of the results, images and lens model."
    " This Jupyter notebook cell with progress once search has completed - this could take some time!"
)

result = search.fit(model=model, analysis=analysis)

print("Search has finished run - you may now continue the notebook.")
# Out:
# The non-linear search has begun running - checkout the autolens_workspace/output/howtolens/chapter_2/tutorial_3_realism_and_complexity folder for live output of the results, images and lens model. This Jupyter notebook cell with progress once search has completed - this could take some time!
# 2025-11-20 14:27:15,236 - autofit.non_linear.search.abstract_search - INFO - Starting non-linear search with 1 cores.
# 2025-11-20 14:27:15,327 - tutorial_3_realism_and_complexity - INFO - The output path of this fit is /Users/rosador/Documents/AGEL/autolens_workspace/output/howtolens/chapter_2/lens_sersic/tutorial_3_realism_and_complexity/c43e84b83726890950a4bcb63dd08e31
# 2025-11-20 14:27:15,538 - tutorial_3_realism_and_complexity - INFO - Fit Already Completed: skipping non-linear search.
# 2025-11-20 14:27:15,614 - tutorial_3_realism_and_complexity - INFO - Removing search internal folder.
# 2025-11-20 14:27:15,615 - tutorial_3_realism_and_complexity - INFO - Removing all files except for .zip file
# 2025-11-20 14:27:15,992 - tutorial_3_realism_and_complexity - INFO - Search complete, returning result
# Search has finished run - you may now continue the notebook.

# %% [markdown]
# __Result__
#
# Inspection of the `info` summary of the result suggests the model has gone to reasonable values.

# %%
print(result.info)
# Out:
# Bayesian Evidence                                                               3323.18030725
# Maximum Log Likelihood                                                          3444.28704830
# Maximum Log Posterior                                                           3447.07767956
#
# model                                                                           Collection (N=20)
#     galaxies                                                                    Collection (N=20)
#         lens                                                                    Galaxy (N=14)
#             bulge                                                               Sersic (N=7)
#             mass                                                                Isothermal (N=5)
#             shear                                                               ExternalShear (N=2)
#         source                                                                  Galaxy (N=6)
#             bulge                                                               ExponentialCore (N=6)
#
# Maximum Log Likelihood Model:
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.000
#                 centre_1                                                        -0.000
#             ell_comps
#                 ell_comps_0                                                     0.053
#                 ell_comps_1                                                     -0.003
#             intensity                                                           1.091
#             effective_radius                                                    0.764
#             sersic_index                                                        3.889
#         mass
#             centre
#                 centre_0                                                        -0.001
#                 centre_1                                                        0.002
#             ell_comps
#                 ell_comps_0                                                     0.053
#                 ell_comps_1                                                     -0.006
#             einstein_radius                                                     1.600
#         shear
#             gamma_1                                                             0.047
#             gamma_2                                                             0.050
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.000
#                 centre_1                                                        0.002
#             ell_comps
#                 ell_comps_0                                                     0.091
#                 ell_comps_1                                                     -0.049
#             effective_radius                                                    0.101
#             intensity                                                           4.016
#
#
# Summary (3.0 sigma limits):
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0022, 0.0011)
#                 centre_1                                                        -0.0007 (-0.0023, 0.0010)
#             ell_comps
#                 ell_comps_0                                                     0.0510 (0.0456, 0.0565)
#                 ell_comps_1                                                     -0.0025 (-0.0081, 0.0030)
#             intensity                                                           1.0897 (1.0255, 1.1552)
#             effective_radius                                                    0.7628 (0.7395, 0.7879)
#             sersic_index                                                        3.8963 (3.7792, 4.0221)
#         mass
#             centre
#                 centre_0                                                        -0.0009 (-0.0033, 0.0017)
#                 centre_1                                                        0.0017 (-0.0007, 0.0041)
#             ell_comps
#                 ell_comps_0                                                     0.0520 (0.0471, 0.0574)
#                 ell_comps_1                                                     -0.0055 (-0.0118, 0.0005)
#             einstein_radius                                                     1.6003 (1.5986, 1.6021)
#         shear
#             gamma_1                                                             0.0474 (0.0446, 0.0501)
#             gamma_2                                                             0.0501 (0.0471, 0.0532)
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0027, 0.0016)
#                 centre_1                                                        0.0019 (-0.0002, 0.0039)
#             ell_comps
#                 ell_comps_0                                                     0.0911 (0.0719, 0.1108)
#                 ell_comps_1                                                     -0.0489 (-0.0640, -0.0351)
#             effective_radius                                                    0.1017 (0.0985, 0.1050)
#             intensity                                                           3.9999 (3.9041, 4.0982)
#
#
# Summary (1.0 sigma limits):
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0011, 0.0000)
#                 centre_1                                                        -0.0007 (-0.0013, -0.0001)
#             ell_comps
#                 ell_comps_0                                                     0.0510 (0.0491, 0.0529)
#                 ell_comps_1                                                     -0.0025 (-0.0043, -0.0006)
#             intensity                                                           1.0897 (1.0687, 1.1107)
#             effective_radius                                                    0.7628 (0.7555, 0.7706)
#             sersic_index                                                        3.8963 (3.8580, 3.9343)
#         mass
#             centre
#                 centre_0                                                        -0.0009 (-0.0018, -0.0001)
#                 centre_1                                                        0.0017 (0.0009, 0.0026)
#             ell_comps
#                 ell_comps_0                                                     0.0520 (0.0503, 0.0538)
#                 ell_comps_1                                                     -0.0055 (-0.0077, -0.0035)
#             einstein_radius                                                     1.6003 (1.5997, 1.6009)
#         shear
#             gamma_1                                                             0.0474 (0.0464, 0.0484)
#             gamma_2                                                             0.0501 (0.0491, 0.0512)
#     source
#         bulge
#             centre
#                 centre_0                                                        -0.0005 (-0.0012, 0.0002)
#                 centre_1                                                        0.0019 (0.0012, 0.0025)
#             ell_comps
#                 ell_comps_0                                                     0.0911 (0.0844, 0.0974)
#                 ell_comps_1                                                     -0.0489 (-0.0539, -0.0439)
#             effective_radius                                                    0.1017 (0.1006, 0.1028)
#             intensity                                                           3.9999 (3.9700, 4.0300)
#
# instances
#
# galaxies
#     lens
#         redshift                                                                0.5
#     source
#         redshift                                                                1.0
#         bulge
#             radius_break                                                        0.025
#             gamma                                                               0.25
#             alpha                                                               3.0

# %% [markdown]
# And lets look at how well the model fits the imaging data, which as we are used to fits the data brilliantly!

# %%
fit_plotter = aplt.FitImagingPlotter(fit=result.max_log_likelihood_fit)
fit_plotter.subplot_fit()

# %% [markdown]
# __Global and Local Maxima__
#
# Up to now, all our non-linear searches have successfully found lens models that provide visibly good fits to the data,
# minimizing residuals and inferring high log likelihood values. These optimal solutions, known as 'global maxima,'
# correspond to the highest likelihood regions across the entire parameter space. In other words, no other lens model
# in the parameter space would yield a higher likelihood. This is the ideal model we always aim to infer.
#
# However, non-linear searches do not always locate these global maxima. They may instead infer 'local maxima'
# solutions, which have high log likelihood values relative to nearby models in the parameter space, but
# significantly lower log likelihoods compared to the true global maxima situated elsewhere.
#
# Why might a non-linear search end up at these local maxima? As previously discussed, the search iterates through
# many models, focusing more on regions of the parameter space where previous guesses yielded higher likelihoods.
# The search gradually 'converges' around any solution with a higher likelihood than surrounding models. If the
# search is not thorough enough, it may settle on a local maxima, appearing to offer a high likelihood
# relative to nearby models but failing to reach the global maxima.
#
# Inferring local maxima is a failure of our non-linear search, and it's something we want to avoid. To illustrate
# this, we can intentionally infer a local maxima by reducing the number of live points (`n_live`) Nautilus uses to
# map out the parameter space. By using very few live points, the initial search over the parameter space has a low
# probability of approaching the global maxima, thus it converges on a local maxima.

# %%
search = af.Nautilus(
    path_prefix=Path("howtolens") / "chapter_2",
    name="tutorial_3_realism_and_complexity__local_maxima",
    unique_tag=dataset_name,
    n_live=75,
)

print(
    "The non-linear search has begun running - checkout the autolens_workspace/output/3_realism_and_complexity"
    " folder for live output of the results, images and lens model."
    " This Jupyter notebook cell with progress once search has completed - this could take some time!"
)
# Out:
# The non-linear search has begun running - checkout the autolens_workspace/output/3_realism_and_complexity folder for live output of the results, images and lens model. This Jupyter notebook cell with progress once search has completed - this could take some time!

# %% [markdown]
# __Run Time__
#
# Due to the decreased number of live points, the estimate of 10000 iterations per free parameter is now a significant
# overestimate. The actual run time of the model-fit will be much less than this.
#
# Run the non-linear search.

# %%
result_local_maxima = search.fit(model=model, analysis=analysis)

print("Search has finished run - you may now continue the notebook.")
# Out:
# 2025-10-24 14:17:56,291 - autofit.non_linear.search.abstract_search - INFO - Starting non-linear search with 1 cores.
# 2025-10-24 14:17:56,331 - tutorial_3_realism_and_complexity__local_maxima - INFO - The output path of this fit is /Users/rosador/Documents/AGEL/autolens_workspace/output/howtolens/chapter_2/lens_sersic/tutorial_3_realism_and_complexity__local_maxima/c8171cb685911fe8eaf88ed1021c75ed
# 2025-10-24 14:17:56,332 - tutorial_3_realism_and_complexity__local_maxima - INFO - Outputting pre-fit files (e.g. model.info, visualization).
# 2025-10-24 14:17:56,807 - tutorial_3_realism_and_complexity__local_maxima - INFO - Starting new Nautilus non-linear search (no previous samples found).
# 2025-10-24 14:17:56,807 - autofit.non_linear.fitness - INFO - JAX: Applying vmap and jit to likelihood function -- may take a few seconds.
# 2025-10-24 14:17:56,807 - autofit.non_linear.fitness - INFO - JAX: vmap and jit applied in 0.0002682209014892578 seconds.
# 2025-10-24 14:17:56,808 - tutorial_3_realism_and_complexity__local_maxima - INFO -
#             Running search where parallelization is disabled.
#
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 63     | 1        | 4        | 10000    | 1.0000 | 1     | -59960.62
# 2025-10-24 14:19:14,209 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 10000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 63     | 1        | 4        | 20000    | 1.0000 | 1     | -59897.06
# 2025-10-24 14:20:11,034 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 20000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 63     | 1        | 4        | 30000    | 1.0000 | 1     | -59881.94
# 2025-10-24 14:21:31,797 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 30000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 64     | 1        | 4        | 40000    | 1.0000 | 1     | -59609.05
# 2025-10-24 14:23:20,086 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 40000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 64     | 1        | 4        | 49950    | 1.0000 | 1     | -59591.91
# 2025-10-24 14:27:25,489 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 50000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 68     | 1        | 4        | 59950    | 1.0000 | 1     | -52499.16
# 2025-10-24 14:28:59,662 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 60000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 69     | 1        | 4        | 69850    | 1.0000 | 1     | -48385.92
# 2025-10-24 14:30:16,101 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 70000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 70     | 1        | 4        | 79800    | 1.0000 | 1     | -46926.52
# 2025-10-24 14:31:52,605 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 80000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 70     | 1        | 4        | 89750    | 1.0000 | 1     | -45984.87
# 2025-10-24 14:36:16,138 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 90000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 71     | 1        | 4        | 99700    | 1.0000 | 1     | -44993.93
# 2025-10-24 14:38:35,341 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 100000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 72     | 1        | 4        | 109500   | 1.0000 | 1     | -43968.79
# 2025-10-24 14:40:56,937 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 110000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 73     | 1        | 4        | 119250   | 1.0000 | 1     | -43323.90
# 2025-10-24 14:43:19,192 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 120000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 117    | 1        | 4        | 128950   | 1.0000 | 1     | -41865.53
# 2025-10-24 14:45:07,894 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 130000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 151    | 1        | 4        | 138550   | 0.8881 | 29    | -41793.25
# 2025-10-24 14:46:51,377 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 140000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 167    | 1        | 4        | 148100   | 0.8314 | 56    | -41780.86
# 2025-10-24 14:48:39,220 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 150000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Stopped   | 185    | 1        | 4        | 157550   | 0.4275 | 230   | -41774.93
# 2025-10-24 14:50:39,997 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 160000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Finished  | 191    | 1        | 4        | 160000   | N/A    | 1638  | -41774.20
# 2025-10-24 14:51:50,095 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Running: Updating results after 170000 iterations (see output folder).
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Finished  | 191    | 1        | 4        | 160000   | N/A    | 1638  | -41774.20
# 2025-10-24 14:52:39,403 - tutorial_3_realism_and_complexity__local_maxima - INFO - Fit Complete: Updating final results (see output folder).
# 2025-10-24 14:53:28,796 - autofit.non_linear.samples.samples - INFO - Samples with weight less than 1e-10 removed from samples.csv.
# 2025-10-24 14:53:29,264 - autofit.non_linear.search.abstract_search - INFO - Creating latent samples by drawing 100 from the PDF.
# 2025-10-24 14:53:29,270 - autofit.non_linear.analysis.analysis - INFO - JAX: Applying vmap and jit to likelihood function for latent variables -- may take a few seconds.
# 2025-10-24 14:53:29,270 - autofit.non_linear.analysis.analysis - INFO - JAX: vmap and jit applied in 0.0004291534423828125 seconds.
# 2025-10-24 14:54:28,373 - tutorial_3_realism_and_complexity__local_maxima - INFO - Removing search internal folder.
# 2025-10-24 14:54:28,375 - tutorial_3_realism_and_complexity__local_maxima - INFO - Removing all files except for .zip file
# 2025-10-24 14:54:28,807 - tutorial_3_realism_and_complexity__local_maxima - INFO - Search complete, returning result
# Search has finished run - you may now continue the notebook.

# %% [markdown]
# __Result__
#
# Inspection of the `info` summary of the result suggests certain parameters have gone to different values to the fit
# performed above.

# %%
print(result_local_maxima.info)
# Out:
# Bayesian Evidence                                                               -41774.20328257
# Maximum Log Likelihood                                                          -41616.52694252
# Maximum Log Posterior                                                           551140.35442008
#
# model                                                                           Collection (N=20)
#     galaxies                                                                    Collection (N=20)
#         lens                                                                    Galaxy (N=14)
#             bulge                                                               Sersic (N=7)
#             mass                                                                Isothermal (N=5)
#             shear                                                               ExternalShear (N=2)
#         source                                                                  Galaxy (N=6)
#             bulge                                                               ExponentialCore (N=6)
#
# Maximum Log Likelihood Model:
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.013
#                 centre_1                                                        -0.013
#             ell_comps
#                 ell_comps_0                                                     0.061
#                 ell_comps_1                                                     0.017
#             intensity                                                           0.156
#             effective_radius                                                    2.597
#             sersic_index                                                        3.005
#         mass
#             centre
#                 centre_0                                                        -0.002
#                 centre_1                                                        0.003
#             ell_comps
#                 ell_comps_0                                                     -0.394
#                 ell_comps_1                                                     0.358
#             einstein_radius                                                     0.076
#         shear
#             gamma_1                                                             0.111
#             gamma_2                                                             -0.169
#     source
#         bulge
#             centre
#                 centre_0                                                        0.005
#                 centre_1                                                        0.003
#             ell_comps
#                 ell_comps_0                                                     0.240
#                 ell_comps_1                                                     -0.129
#             effective_radius                                                    0.166
#             intensity                                                           22.221
#
#
# Summary (3.0 sigma limits):
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.0125 (-0.0125, -0.0125)
#                 centre_1                                                        -0.0125 (-0.0125, -0.0125)
#             ell_comps
#                 ell_comps_0                                                     0.0605 (0.0574, 0.0626)
#                 ell_comps_1                                                     0.0171 (0.0145, 0.0188)
#             intensity                                                           0.1562 (0.1534, 0.1621)
#             effective_radius                                                    2.5942 (2.5422, 2.6240)
#             sersic_index                                                        3.0030 (2.9152, 3.0546)
#         mass
#             centre
#                 centre_0                                                        -0.0008 (-0.0026, 0.0004)
#                 centre_1                                                        0.0025 (-0.0043, 0.0040)
#             ell_comps
#                 ell_comps_0                                                     -0.3757 (-0.4490, -0.3491)
#                 ell_comps_1                                                     0.3360 (0.2700, 0.3588)
#             einstein_radius                                                     0.0748 (0.0729, 0.0801)
#         shear
#             gamma_1                                                             0.1096 (0.0593, 0.1210)
#             gamma_2                                                             -0.1690 (-0.1855, -0.1258)
#     source
#         bulge
#             centre
#                 centre_0                                                        0.0051 (0.0044, 0.0059)
#                 centre_1                                                        0.0028 (0.0019, 0.0040)
#             ell_comps
#                 ell_comps_0                                                     0.2427 (0.1929, 0.2596)
#                 ell_comps_1                                                     -0.1249 (-0.1411, -0.0542)
#             effective_radius                                                    0.1660 (0.1640, 0.1673)
#             intensity                                                           22.1207 (21.7459, 22.5690)
#
#
# Summary (1.0 sigma limits):
#
# galaxies
#     lens
#         bulge
#             centre
#                 centre_0                                                        -0.0125 (-0.0125, -0.0125)
#                 centre_1                                                        -0.0125 (-0.0125, -0.0125)
#             ell_comps
#                 ell_comps_0                                                     0.0605 (0.0597, 0.0613)
#                 ell_comps_1                                                     0.0171 (0.0165, 0.0177)
#             intensity                                                           0.1562 (0.1552, 0.1574)
#             effective_radius                                                    2.5942 (2.5835, 2.6047)
#             sersic_index                                                        3.0030 (2.9833, 3.0213)
#         mass
#             centre
#                 centre_0                                                        -0.0008 (-0.0013, -0.0003)
#                 centre_1                                                        0.0025 (0.0019, 0.0030)
#             ell_comps
#                 ell_comps_0                                                     -0.3757 (-0.3871, -0.3656)
#                 ell_comps_1                                                     0.3360 (0.3260, 0.3439)
#             einstein_radius                                                     0.0748 (0.0740, 0.0756)
#         shear
#             gamma_1                                                             0.1096 (0.1065, 0.1126)
#             gamma_2                                                             -0.1690 (-0.1751, -0.1631)
#     source
#         bulge
#             centre
#                 centre_0                                                        0.0051 (0.0049, 0.0053)
#                 centre_1                                                        0.0028 (0.0025, 0.0031)
#             ell_comps
#                 ell_comps_0                                                     0.2427 (0.2369, 0.2491)
#                 ell_comps_1                                                     -0.1249 (-0.1286, -0.1212)
#             effective_radius                                                    0.1660 (0.1655, 0.1665)
#             intensity                                                           22.1207 (22.0285, 22.2079)
#
# instances
#
# galaxies
#     lens
#         redshift                                                                0.5
#     source
#         redshift                                                                1.0
#         bulge
#             radius_break                                                        0.025
#             gamma                                                               0.25
#             alpha                                                               3.0

# %% [markdown]
# Lats look at the fit to the `Imaging` data, which is clearly worse than our original fit above.

# %%
fit_plotter = aplt.FitImagingPlotter(fit=result_local_maxima.max_log_likelihood_fit)
fit_plotter.subplot_fit()

# %% [markdown]
# Finally, just to be sure we hit a local maxima, lets compare the maximum log likelihood values of the two results
#
# The local maxima value is significantly lower, confirming that our non-linear search simply failed to locate lens
# models which fit the data better when it searched parameter space.

# %%
print("Likelihood of Global Model:")
print(result.max_log_likelihood_fit.log_likelihood)
print("Likelihood of Local Model:")
print(result_local_maxima.max_log_likelihood_fit.log_likelihood)
# Out:
# Likelihood of Global Model:
# 3444.287048295191
# Likelihood of Local Model:
# -41616.52694252262

# %% [markdown]
# __Wrap Up__
#
# In this example, we intentionally made our non-linear search fail, by using so few live points it had no hope of
# sampling parameter space thoroughly. For modeling real lenses we wouldn't do this intentionally, but the risk of
# inferring a local maxima is still very real, especially as we make our lens model more complex.
#
# Lets think about *complexity*. As we make our lens model more realistic, we also made it more complex. For this
# tutorial, our non-linear parameter space went from 7 dimensions to 18. This means there was a much larger *volume* of
# parameter space to search. As this volume grows, there becomes a higher chance that our non-linear search gets lost
# and infers a local maxima, especially if we don't set it up with enough live points!
#
# At its core, lens modeling is all about learning how to get a non-linear search to find the global maxima region of
# parameter space, even when the lens model is complex. This will be the main theme throughout the rest of this chapter
# and is the main subject of chapter 3.
#
# In the next exercise, we'll learn how to deal with failure and begin thinking about how we can ensure our non-linear
# search finds the global-maximum log likelihood solution. First, think about the following:
#
#  1) When you look at an image of a strong lens, do you get a sense of roughly what values certain lens model
#  parameters are?
#
#  2) The non-linear search failed because parameter space was too complex. Could we make it less complex, whilst
#  still keeping our lens model fairly realistic?
#
#  3) The source galaxy in this example had only 7 non-linear parameters. Real source galaxies may have multiple
#  components (e.g. a disk, bulge, bar, star-forming knot) and there may even be more than 1 source galaxy! Do you
#  think there is any hope of us navigating a parameter space if the source contributes 20+ parameters by itself?
