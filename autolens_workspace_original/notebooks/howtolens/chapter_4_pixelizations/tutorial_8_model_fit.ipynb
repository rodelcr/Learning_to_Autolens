# %% [markdown]
# Tutorial 8: Model-Fit
# =====================
#
# To illustrate lens modeling using an inversion this tutorial revists revisit the complex source model-fit that we
# performed in tutorial 6 of chapter 3. This time, as you have probably guessed, we will fit the complex source using
# an inversion.
#
# We will use search chaining to do this, first fitting the source with a light profile, thereby initialize the mass
# model priors and avoiding the unphysical solutions discussed in tutorial 6. In the later searches we will switch to
# an `Inversion`.

# %%
# %matplotlib inline
from pyprojroot import here
workspace_path = str(here())
# %cd $workspace_path
print(f"Working Directory has been set to `{workspace_path}`")

from pathlib import Path
import autofit as af
import autolens as al
import autolens.plot as aplt
# Out:
# /Users/rosador/Documents/AGEL/autolens_workspace
# Working Directory has been set to `/Users/rosador/Documents/AGEL/autolens_workspace`
#
# ***JAX ENABLED***
#
# Using JAX for grad/jit and GPU/TPU acceleration.
# To disable JAX, set: config -> general -> jax -> use_jax = false
#
# JAX mode enabled

# %% [markdown]
# __Initial Setup__
#
# we'll use strong lensing data, where:
#
#  - The lens galaxy's light is omitted.
#  - The lens galaxy's total mass distribution is an `Isothermal` and `ExternalShear`.
#  - The source galaxy's light is four `Sersic`.

# %%
dataset_name = "source_complex"
dataset_path = Path("dataset") / "imaging" / dataset_name

dataset = al.Imaging.from_fits(
    data_path=dataset_path / "data.fits",
    noise_map_path=dataset_path / "noise_map.fits",
    psf_path=dataset_path / "psf.fits",
    pixel_scales=0.05,
)

mask_radius = 3.6

mask = al.Mask2D.circular(
    shape_native=dataset.shape_native,
    pixel_scales=dataset.pixel_scales,
    radius=mask_radius,
)


dataset = dataset.apply_mask(mask=mask)

dataset_plotter = aplt.ImagingPlotter(
    dataset=dataset, visuals_2d=aplt.Visuals2D(mask=mask)
)
dataset_plotter.subplot_dataset()
# Out:
# 2025-11-20 13:29:23,833 - jax._src.xla_bridge - INFO - Unable to initialize backend 'cuda':
# 2025-11-20 13:29:23,833 - jax._src.xla_bridge - INFO - Unable to initialize backend 'rocm': module 'jaxlib.xla_extension' has no attribute 'GpuAllocatorConfig'
# 2025-11-20 13:29:23,834 - jax._src.xla_bridge - INFO - Unable to initialize backend 'tpu': INTERNAL: Failed to open libtpu.so: dlopen(libtpu.so, 0x0001): tried: 'libtpu.so' (no such file), '/System/Volumes/Preboot/Cryptexes/OSlibtpu.so' (no such file), '/opt/anaconda3/envs/autolens/bin/../lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache), 'libtpu.so' (no such file), '/usr/local/lib/libtpu.so' (no such file), '/usr/lib/libtpu.so' (no such file, not in dyld cache)
# 2025-11-20 13:29:24,574 - autoarray.dataset.imaging.dataset - INFO - Imaging data has been trimmed or padded for FFT convolution.
#   - Original shape : (170, 170)
#   - FFT shape    : (180, 180)
# Padding ensures accurate PSF convolution in Fourier space. Set `disable_fft_pad=True` in Imaging object to turn off automatic padding.
# 2025-11-20 13:29:25,040 - autoarray.dataset.imaging.dataset - INFO - IMAGING - Data masked, contains a total of 16292 image-pixels

# %% [markdown]
# __Model + Search + Analysis + Model-Fit (Search 1)__
#
# Search 1 fits a lens model where:
#
#  - The lens galaxy's total mass distribution is an `Isothermal` with `ExternalShear` [7 parameters].
#
#  - The source galaxy's light is a parametric `SersicCore` [7 parameters].
#
# The number of free parameters and therefore the dimensionality of non-linear parameter space is N=14.

# %%
model_1 = af.Collection(
    galaxies=af.Collection(
        lens=af.Model(
            al.Galaxy,
            redshift=0.5,
            mass=al.mp.Isothermal,
            shear=al.mp.ExternalShear,
        ),
        source=af.Model(al.Galaxy, redshift=1.0, bulge=al.lp.Sersic),
    ),
)

search_1 = af.Nautilus(
    path_prefix=Path("howtolens", "chapter_4"),
    name="search[1]_mass[sie]_source[lp]",
    unique_tag=dataset_name,
    n_live=100,
)

analysis_1 = al.AnalysisImaging(dataset=dataset)

result_1 = search_1.fit(model=model_1, analysis=analysis_1)
# Out:
# 2025-11-20 13:29:31,299 - autofit.non_linear.search.abstract_search - INFO - Starting non-linear search with 1 cores.
# 2025-11-20 13:29:31,364 - search[1]_mass[sie]_source[lp] - INFO - The output path of this fit is /Users/rosador/Documents/AGEL/autolens_workspace/output/howtolens/chapter_4/source_complex/search[1]_mass[sie]_source[lp]/30cc7b9c4f519e28f46e16ec95ea040b
# 2025-11-20 13:29:31,415 - search[1]_mass[sie]_source[lp] - INFO - Fit Already Completed: skipping non-linear search.
# 2025-11-20 13:29:31,490 - search[1]_mass[sie]_source[lp] - INFO - Removing search internal folder.
# 2025-11-20 13:29:31,490 - search[1]_mass[sie]_source[lp] - INFO - Removing all files except for .zip file
# 2025-11-20 13:29:31,732 - search[1]_mass[sie]_source[lp] - INFO - Search complete, returning result

# %%
model_1 = af.Collection(
    galaxies=af.Collection(
        lens=af.Model(
            al.Galaxy,
            redshift=0.5,
            mass=al.mp.Isothermal,
            shear=al.mp.ExternalShear,
        ),
        source=af.Model(
            al.Galaxy,
            redshift=1.0,
            pixelization=af.Model(
                al.Pixelization,
                image_mesh=None,
                mesh=al.mesh.Rectangular,
                regularization=al.reg.Constant,
            ),)
        ),
    ),


search_1 = af.Nautilus(
    path_prefix=Path("howtolens", "chapter_4"),
    name="search[1]_mass[sie]_source[lp]",
    unique_tag=dataset_name,
    n_live=100,
)

analysis_1 = al.AnalysisImaging(dataset=dataset)

result_1 = search_1.fit(model=model_1, analysis=analysis_1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 31
#      22 search_1 = af.Nautilus(
#      23     path_prefix=Path("howtolens", "chapter_4"),
#      24     name="search[1]_mass[sie]_source[lp]",
#      25     unique_tag=dataset_name,
#      26     n_live=100,
#      27 )
#      29 analysis_1 = al.AnalysisImaging(dataset=dataset)
# ---> 31 result_1 = search_1.fit(model=model_1, analysis=analysis_1)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/abstract_search.py:474, in NonLinearSearch.fit(self, model, analysis, info)
#     435 def fit(
#     436     self,
#     437     model: AbstractPriorModel,
#     438     analysis: Analysis,
#     439     info: Optional[Dict] = None,
#     440 ) -> Union[Result, List[Result]]:
#     441     """
#     442     Fit a model, M with some function f that takes instances of the
#     443     class represented by model M and gives a score for their fitness.
#    (...)    472         If the model has 0 dimensions.
#     473     """
# --> 474     self.check_model(model=model)
#     476     logger.info(f"Starting non-linear search with {self.number_of_cores} cores.")
#     477     self._log_process_state()
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/abstract_search.py:776, in NonLinearSearch.check_model(self, model)
#     775 def check_model(self, model: AbstractPriorModel):
# --> 776     if model is not None and model.prior_count == 0:
#     777         raise AssertionError("Model has no priors! Cannot fit a 0 dimension model.")
#
# AttributeError: 'tuple' object has no attribute 'prior_count'

# %% [markdown]
# __Position Likelihood (Search 2)__
#
# We add a penalty term ot the likelihood function, which penalizes models where the brightest multiple images of
# the lensed source galaxy do not trace close to one another in the source plane. This removes "demagnified source
# solutions" from the source pixelization, which one is likely to infer without this penalty.
#
# A comprehensive description of why we do this is given at the following readthedocs page.
#
# You were directed to this page in tutorial 6, however I suggest you reread the section "Auto Position Updates" as
# we will be using this functionality below.
#
#  https://pyautolens.readthedocs.io/en/latest/general/demagnified_solutions.html
#
# __Model + Search + Analysis + Model-Fit (Search 2)__
#
# We use the results of search 1 to create the lens model fitted in search 2, where:
#
#  - The lens galaxy's total mass distribution is an `Isothermal` and `ExternalShear` [Parameters fixed to
#  results of search 1].
#
#  - The source galaxy's pixelization uses an `Overlay` image-mesh [2 parameters]
#
#  - The source-galaxy's pixelization uses a `Rectangular` mesh [0 parameters].
#
#  - This pixelization is regularized using a `Constant` scheme [1 parameter].
#
# The number of free parameters and therefore the dimensionality of non-linear parameter space is N=3.
#
# This search allows us to very efficiently set up the resolution of the mesh and regularization coefficient
# of the regularization scheme, before using these models to refit the lens mass model.
#
# Also, note how we can pass the `al.SettingsInversion` object to an analysis class to customize if the border relocation
# is used.

# %%
model_2 = af.Collection(
    galaxies=af.Collection(
        lens=af.Model(
            al.Galaxy,
            redshift=0.5,
            mass=result_1.instance.galaxies.lens.mass,
            shear=result_1.instance.galaxies.lens.shear,
        ),
        source=af.Model(
            al.Galaxy,
            redshift=1.0,
            pixelization=af.Model(
                al.Pixelization,
                image_mesh=None,
                mesh=al.mesh.Rectangular,
                regularization=al.reg.Constant,
            ),
        ),
    ),
)

search_2 = af.Nautilus(
    path_prefix=Path("howtolens", "chapter_4"),
    name="search[2]_mass[sie]_source[pix_init]",
    unique_tag=dataset_name,
    n_live=50,
)

analysis_2 = al.AnalysisImaging(
    dataset=dataset,
    positions_likelihood_list=[
        result_1.positions_likelihood_from(factor=3.0, minimum_threshold=0.2)
    ],
    settings_inversion=al.SettingsInversion(use_border_relocator=True),
)

# %% [markdown]
# __Run Time__
#
# The run time of a pixelization is longer than many other features, with the estimate below coming out at around ~0.5
# seconds per likelihood evaluation. This is because the fit has a lot of linear algebra to perform in order to
# reconstruct the source on the pixel-grid.
#
# Nevertheless, this is still fast enough for most use-cases. If run-time is an issue, the following factors determine
# the run-time of a a pixelization and can be changed to speed it up (at the expense of accuracy):
#
#  - The number of unmasked pixels in the image data. By making the mask smaller (e.g. using an annular mask), the
#    run-time will decrease.
#
#  - The number of source pixels in the pixelization. By reducing the `shape` from (30, 30) the run-time will decrease.
#
# This also serves to highlight why the positions threshold likelihood is so powerful. The likelihood evaluation time
# of this step is below 0.001 seconds, meaning that the initial parameter space sampling is extremely efficient even
# for a pixelization (this is not accounted for in the run-time estimate below)!
#
# __Model Fit__
#
# Run the search.

# %%
result_2 = search_2.fit(model=model_2, analysis=analysis_2)
# Out:
# 2025-11-20 13:29:39,448 - autofit.non_linear.search.abstract_search - INFO - Starting non-linear search with 1 cores.
# 2025-11-20 13:29:39,492 - search[2]_mass[sie]_source[pix_init] - INFO - The output path of this fit is /Users/rosador/Documents/AGEL/autolens_workspace/output/howtolens/chapter_4/source_complex/search[2]_mass[sie]_source[pix_init]/5531853a847ebecf81ee4af8cfcae0a0
# 2025-11-20 13:29:39,492 - search[2]_mass[sie]_source[pix_init] - INFO - Outputting pre-fit files (e.g. model.info, visualization).
# 2025-11-20 13:29:40,256 - search[2]_mass[sie]_source[pix_init] - INFO - Starting new Nautilus non-linear search (no previous samples found).
# 2025-11-20 13:29:40,257 - autofit.non_linear.fitness - INFO - JAX: Applying vmap and jit to likelihood function -- may take a few seconds.
# 2025-11-20 13:29:40,257 - autofit.non_linear.fitness - INFO - JAX: vmap and jit applied in 0.00042700767517089844 seconds.
# 2025-11-20 13:29:40,258 - search[2]_mass[sie]_source[pix_init] - INFO -
#             Running search where parallelization is disabled.
#
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Computing | 1      | 0        | 0        | 0        | 1.0000 | 0     | N/A
# ---------------------------------------------------------------------------
# TracerBoolConversionError                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 result_2 = search_2.fit(model=model_2, analysis=analysis_2)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/abstract_search.py:496, in NonLinearSearch.fit(self, model, analysis, info)
#     489 self.pre_fit_output(
#     490     analysis=analysis,
#     491     model=model,
#     492     info=info,
#     493 )
#     495 if not self.paths.is_complete:
# --> 496     result = self.start_resume_fit(
#     497         analysis=analysis,
#     498         model=model,
#     499     )
#     500 else:
#     501     result = self.result_via_completed_fit(
#     502         analysis=analysis,
#     503         model=model,
#     504     )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/abstract_search.py:118, in configure_handler.<locals>.decorated(self, *args, **kwargs)
#     115     return func(self, *args, **kwargs)
#     117 try:
# --> 118     return func(self, *args, **kwargs)
#     119 finally:
#     120     root_logger.removeHandler(handler)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/abstract_search.py:644, in NonLinearSearch.start_resume_fit(self, analysis, model)
#     641     self.timer.start()
#     643 model.freeze()
# --> 644 search_internal, fitness = self._fit(
#     645     model=model,
#     646     analysis=analysis,
#     647 )
#     649 samples = self.perform_update(
#     650     model=model,
#     651     analysis=analysis,
#    (...)    654     during_analysis=False,
#     655 )
#     657 result = analysis.make_result(
#     658     samples_summary=samples.summary(),
#     659     paths=self.paths,
#     660     samples=samples,
#     661     search_internal=search_internal,
#     662 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/nest/nautilus/search.py:142, in Nautilus._fit(self, model, analysis)
#     127 if (
#     128     self.config_dict.get("force_x1_cpu")
#     129     or self.kwargs.get("force_x1_cpu")
#     130     or jax_wrapper.use_jax
#     131 ):
#     133     fitness = Fitness(
#     134         model=model,
#     135         analysis=analysis,
#    (...)    139         use_jax_vmap=True,
#     140     )
# --> 142     search_internal = self.fit_x1_cpu(
#     143         fitness=fitness,
#     144         model=model,
#     145         analysis=analysis,
#     146     )
#     147 else:
#     149     fitness = Fitness(
#     150         model=model,
#     151         analysis=analysis,
#    (...)    154         resample_figure_of_merit=-1.0e99,
#     155     )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/nest/nautilus/search.py:231, in Nautilus.fit_x1_cpu(self, fitness, model, analysis)
#     219 config_dict.pop("vectorized")
#     221 search_internal = self.sampler_cls(
#     222     prior=PriorVectorized(model=model),
#     223     likelihood=fitness.call_wrap,
#    (...)    228     **config_dict,
#     229 )
# --> 231 return self.call_search(search_internal=search_internal, model=model, analysis=analysis, fitness=fitness)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/nest/nautilus/search.py:327, in Nautilus.call_search(self, search_internal, model, analysis, fitness)
#     317 iterations, total_iterations = self.iterations_from(
#     318     search_internal=search_internal
#     319 )
#     321 config_dict_run = {
#     322     key: value
#     323     for key, value in self.config_dict_run.items()
#     324     if key != "n_like_max"
#     325 }
# --> 327 search_internal.run(
#     328     **config_dict_run,
#     329     n_like_max=iterations,
#     330 )
#     332 iterations_after_run = self.iterations_from(search_internal=search_internal)[1]
#     334 if (
#     335         total_iterations == iterations_after_run
#     336         or iterations_after_run == self.config_dict_run["n_like_max"]
#     337 ):
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/nautilus/sampler.py:441, in Sampler.run(self, f_live, n_shell, n_eff, n_like_max, discard_exploration, timeout, verbose)
#     438     if self.filepath is not None:
#     439         self.write(self.filepath, overwrite=True)
# --> 441 self.n_update_iter += self.add_samples(-1, verbose=verbose)
#     442 self.n_like_iter += self.n_batch
#     443 if self.filepath is not None:
#     444     # Write the complete file if this is the first batch.
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/nautilus/sampler.py:1119, in Sampler.add_samples(self, shell, verbose)
#    1116         self.print_status('Computing', end='\r')
#    1118 self.shell_n_sample[shell] += n_bound
# -> 1119 log_l, blobs = self.evaluate_likelihood(points)
#    1120 self.points[shell] = np.append(self.points[shell], points, axis=0)
#    1121 self.log_l[shell] = np.append(self.log_l[shell], log_l, axis=0)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/nautilus/sampler.py:865, in Sampler.evaluate_likelihood(self, points)
#     863 # Evaluate the likelihood.
#     864 if self.vectorized:
# --> 865     result = self.likelihood(args)
#     866     if isinstance(result, tuple):
#     867         result = list(zip(*result))
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/fitness.py:196, in Fitness.call_wrap(self, parameters)
#     193     if len(np.array(parameters).shape) == 1:
#     194         parameters = np.array(parameters)[None, :]
# --> 196 figure_of_merit = self._call(parameters)
#     198 if self.fom_is_log_likelihood:
#     199     log_likelihood = figure_of_merit
#
#     [... skipping hidden 14 frame]
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/fitness.py:144, in Fitness.call(self, parameters)
#     127 """
#     128 A private method that calls the fitness function with the given parameters and additional keyword arguments.
#     129 This method is intended for internal use only.
#    (...)    141 The figure of merit returned to the non-linear search, which is either the log likelihood or log posterior.
#     142 """
#     143 # Get instance from model
# --> 144 instance = self.model.instance_from_vector(vector=parameters)
#     146 # Evaluate log likelihood (must be side-effect free and exception-free)
#     147 log_likelihood = self.analysis.log_likelihood_function(instance=instance)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:780, in AbstractPriorModel.instance_from_vector(self, vector, ignore_assertions)
#     769     raise AssertionError(
#     770         f"Vector length {len(vector)} != prior count {self.prior_count}"
#     771     )
#     772 arguments = dict(
#     773     map(
#     774         lambda prior_tuple, physical_unit: (prior_tuple.prior, physical_unit),
#    (...)    777     )
#     778 )
# --> 780 return self.instance_for_arguments(
#     781     arguments,
#     782     ignore_assertions=ignore_assertions,
#     783 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/collection.py:231, in Collection._instance_for_arguments(self, arguments, ignore_assertions)
#     229     continue
#     230 if isinstance(value, AbstractPriorModel):
# --> 231     value = value.instance_for_arguments(
#     232         arguments,
#     233         ignore_assertions=ignore_assertions,
#     234     )
#     235 elif isinstance(value, Prior):
#     236     value = arguments[value]
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/collection.py:231, in Collection._instance_for_arguments(self, arguments, ignore_assertions)
#     229     continue
#     230 if isinstance(value, AbstractPriorModel):
# --> 231     value = value.instance_for_arguments(
#     232         arguments,
#     233         ignore_assertions=ignore_assertions,
#     234     )
#     235 elif isinstance(value, Prior):
#     236     value = arguments[value]
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/prior_model.py:494, in Model._instance_for_arguments(self, arguments, ignore_assertions)
#     490 for prior_model_tuple in self.direct_prior_model_tuples:
#     491     prior_model = prior_model_tuple.prior_model
#     492     model_arguments[
#     493         prior_model_tuple.name
# --> 494     ] = prior_model.instance_for_arguments(
#     495         arguments,
#     496         ignore_assertions=ignore_assertions,
#     497     )
#     499 prior_arguments = dict()
#     501 for name, prior in self.direct_prior_tuples:
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/prior_model.py:494, in Model._instance_for_arguments(self, arguments, ignore_assertions)
#     490 for prior_model_tuple in self.direct_prior_model_tuples:
#     491     prior_model = prior_model_tuple.prior_model
#     492     model_arguments[
#     493         prior_model_tuple.name
# --> 494     ] = prior_model.instance_for_arguments(
#     495         arguments,
#     496         ignore_assertions=ignore_assertions,
#     497     )
#     499 prior_arguments = dict()
#     501 for name, prior in self.direct_prior_tuples:
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/prior_model.py:526, in Model._instance_for_arguments(self, arguments, ignore_assertions)
#     524     cls(result, **constructor_arguments)
#     525 else:
# --> 526     result = self.cls(**constructor_arguments)
#     528 for key, value in self.__dict__.items():
#     529     if (
#     530         not hasattr(result, key)
#     531         and not isinstance(value, Prior)
#     532         and not key == "cls"
#     533         and not key.startswith("_")
#     534     ):
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autoarray/inversion/pixelization/mesh/rectangular.py:46, in Rectangular.__init__(self, shape)
#      17 def __init__(self, shape: Tuple[int, int] = (3, 3)):
#      18     """
#      19     A uniform mesh of rectangular pixels, which without interpolation are paired with a 2D grid of (y,x)
#      20     coordinates.
#    (...)     43         The 2D dimensions of the rectangular grid of pixels (total_y_pixels, total_x_pixel).
#      44     """
# ---> 46     if shape[0] <= 2 or shape[1] <= 2:
#      47         raise exc.MeshException(
#      48             "The rectangular pixelization must be at least dimensions 3x3"
#      49         )
#      51     self.shape = (int(shape[0]), int(shape[1]))
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/jax/_src/core.py:1475, in concretization_function_error.<locals>.error(self, arg)
#    1474 def error(self, arg):
# -> 1475   raise TracerBoolConversionError(arg)
#
# TracerBoolConversionError: Attempted boolean conversion of traced array with shape bool[]..
# The error occurred while tracing the function call at /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/fitness.py:126 for jit. This concrete value was not available in Python because it depends on the value of the argument parameters.
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerBoolConversionError

# %% [markdown]
# __Model + Search (Search 3)__
#
# We use the results of searches 1 and 2 to create the lens model fitted in search 3, where:
#
#  - The lens galaxy's total mass distribution is an `Isothermal` and `ExternalShear` [7 parameters: priors
#  initialized from search 1].
#
#  - The source galaxy's pixelization uses an `Overlay` image-mesh [parameters fixed to results of search 2].
#
#  - The source-galaxy's pixelization uses a `Rectangular` mesh [parameters fixed to results of search 2].
#
#  - This pixelization is regularized using a `Constant` scheme [parameters fixed to results of search 2].
#
# The number of free parameters and therefore the dimensionality of non-linear parameter space is N=7.
#
# This search therefore refits the lens mass model using the pixelized source.

# %%
model_3 = af.Collection(
    galaxies=af.Collection(
        lens=af.Model(
            al.Galaxy,
            redshift=0.5,
            mass=result_1.model.galaxies.lens.mass,
            shear=result_1.model.galaxies.lens.shear,
        ),
        source=af.Model(
            al.Galaxy,
            redshift=1.0,
            pixelization=af.Model(
                al.Pixelization,
                image_mesh=None,
                mesh=al.mesh.Rectangular,
                regularization=al.reg.Constant)#result_2.instance.galaxies.source.pixelization,
        ),
    ),
)

search_3 = af.Nautilus(
    path_prefix=Path("howtolens", "chapter_4"),
    name="search[3]_mass[sie]_source[pix]",
    unique_tag=dataset_name,
    n_live=100,
)

# %% [markdown]
# __Positions + Analysis + Model-Fit (Search 3)__
#
# The unphysical solutions that can occur in an `Inversion` can be mitigated by using a positions threshold to penalize
# mass models where the source's brightest lensed pixels do not trace close to one another. With search chaining, we can
# in fact use the model-fit of a previous search (in this example, search 1) to compute the positions that we use in a
# later search.
#
# Below, we use the results of the first search to compute the lensed source positions that are input into search 2. The
# code below uses the  maximum log likelihood model mass model and source galaxy centre, to determine where the source
# positions are located in the image-plane.
#
# We also use this result to set the `position_threshold`, whereby the threshold value is based on how close these
# positions trace to one another in the source-plane (using the best-fit mass model again). This threshold is multiplied
# by a `factor` to ensure it is not too small (and thus does not remove plausible mass  models). If, after this
# multiplication, the threshold is below the `minimum_threshold`, it is rounded up to this minimum value.

# %%
analysis_3 = al.AnalysisImaging(
    dataset=dataset,
    positions_likelihood_list=[
        result_1.positions_likelihood_from(factor=3.0, minimum_threshold=0.2)
    ],
)

result_3 = search_3.fit(model=model_3, analysis=analysis_3)
# Out:
# 2025-11-20 13:29:45,275 - autofit.non_linear.search.abstract_search - INFO - Starting non-linear search with 1 cores.
# 2025-11-20 13:29:45,303 - search[3]_mass[sie]_source[pix] - INFO - The output path of this fit is /Users/rosador/Documents/AGEL/autolens_workspace/output/howtolens/chapter_4/source_complex/search[3]_mass[sie]_source[pix]/671accae694cd77decf0e1677cd76d16
# 2025-11-20 13:29:45,304 - search[3]_mass[sie]_source[pix] - INFO - Outputting pre-fit files (e.g. model.info, visualization).
# 2025-11-20 13:29:45,954 - search[3]_mass[sie]_source[pix] - INFO - Starting new Nautilus non-linear search (no previous samples found).
# 2025-11-20 13:29:45,955 - autofit.non_linear.fitness - INFO - JAX: Applying vmap and jit to likelihood function -- may take a few seconds.
# 2025-11-20 13:29:45,955 - autofit.non_linear.fitness - INFO - JAX: vmap and jit applied in 0.0003590583801269531 seconds.
# 2025-11-20 13:29:45,956 - search[3]_mass[sie]_source[pix] - INFO -
#             Running search where parallelization is disabled.
#
# Starting the nautilus sampler...
# Please report issues at github.com/johannesulf/nautilus.
# Status    | Bounds | Ellipses | Networks | Calls    | f_live | N_eff | log Z
# Computing | 1      | 0        | 0        | 0        | 1.0000 | 0     | N/A
# ---------------------------------------------------------------------------
# TracerBoolConversionError                 Traceback (most recent call last)
# Cell In[7], line 8
#       1 analysis_3 = al.AnalysisImaging(
#       2     dataset=dataset,
#       3     positions_likelihood_list=[
#       4         result_1.positions_likelihood_from(factor=3.0, minimum_threshold=0.2)
#       5     ],
#       6 )
# ----> 8 result_3 = search_3.fit(model=model_3, analysis=analysis_3)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/abstract_search.py:496, in NonLinearSearch.fit(self, model, analysis, info)
#     489 self.pre_fit_output(
#     490     analysis=analysis,
#     491     model=model,
#     492     info=info,
#     493 )
#     495 if not self.paths.is_complete:
# --> 496     result = self.start_resume_fit(
#     497         analysis=analysis,
#     498         model=model,
#     499     )
#     500 else:
#     501     result = self.result_via_completed_fit(
#     502         analysis=analysis,
#     503         model=model,
#     504     )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/abstract_search.py:118, in configure_handler.<locals>.decorated(self, *args, **kwargs)
#     115     return func(self, *args, **kwargs)
#     117 try:
# --> 118     return func(self, *args, **kwargs)
#     119 finally:
#     120     root_logger.removeHandler(handler)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/abstract_search.py:644, in NonLinearSearch.start_resume_fit(self, analysis, model)
#     641     self.timer.start()
#     643 model.freeze()
# --> 644 search_internal, fitness = self._fit(
#     645     model=model,
#     646     analysis=analysis,
#     647 )
#     649 samples = self.perform_update(
#     650     model=model,
#     651     analysis=analysis,
#    (...)    654     during_analysis=False,
#     655 )
#     657 result = analysis.make_result(
#     658     samples_summary=samples.summary(),
#     659     paths=self.paths,
#     660     samples=samples,
#     661     search_internal=search_internal,
#     662 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/nest/nautilus/search.py:142, in Nautilus._fit(self, model, analysis)
#     127 if (
#     128     self.config_dict.get("force_x1_cpu")
#     129     or self.kwargs.get("force_x1_cpu")
#     130     or jax_wrapper.use_jax
#     131 ):
#     133     fitness = Fitness(
#     134         model=model,
#     135         analysis=analysis,
#    (...)    139         use_jax_vmap=True,
#     140     )
# --> 142     search_internal = self.fit_x1_cpu(
#     143         fitness=fitness,
#     144         model=model,
#     145         analysis=analysis,
#     146     )
#     147 else:
#     149     fitness = Fitness(
#     150         model=model,
#     151         analysis=analysis,
#    (...)    154         resample_figure_of_merit=-1.0e99,
#     155     )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/nest/nautilus/search.py:231, in Nautilus.fit_x1_cpu(self, fitness, model, analysis)
#     219 config_dict.pop("vectorized")
#     221 search_internal = self.sampler_cls(
#     222     prior=PriorVectorized(model=model),
#     223     likelihood=fitness.call_wrap,
#    (...)    228     **config_dict,
#     229 )
# --> 231 return self.call_search(search_internal=search_internal, model=model, analysis=analysis, fitness=fitness)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/search/nest/nautilus/search.py:327, in Nautilus.call_search(self, search_internal, model, analysis, fitness)
#     317 iterations, total_iterations = self.iterations_from(
#     318     search_internal=search_internal
#     319 )
#     321 config_dict_run = {
#     322     key: value
#     323     for key, value in self.config_dict_run.items()
#     324     if key != "n_like_max"
#     325 }
# --> 327 search_internal.run(
#     328     **config_dict_run,
#     329     n_like_max=iterations,
#     330 )
#     332 iterations_after_run = self.iterations_from(search_internal=search_internal)[1]
#     334 if (
#     335         total_iterations == iterations_after_run
#     336         or iterations_after_run == self.config_dict_run["n_like_max"]
#     337 ):
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/nautilus/sampler.py:441, in Sampler.run(self, f_live, n_shell, n_eff, n_like_max, discard_exploration, timeout, verbose)
#     438     if self.filepath is not None:
#     439         self.write(self.filepath, overwrite=True)
# --> 441 self.n_update_iter += self.add_samples(-1, verbose=verbose)
#     442 self.n_like_iter += self.n_batch
#     443 if self.filepath is not None:
#     444     # Write the complete file if this is the first batch.
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/nautilus/sampler.py:1119, in Sampler.add_samples(self, shell, verbose)
#    1116         self.print_status('Computing', end='\r')
#    1118 self.shell_n_sample[shell] += n_bound
# -> 1119 log_l, blobs = self.evaluate_likelihood(points)
#    1120 self.points[shell] = np.append(self.points[shell], points, axis=0)
#    1121 self.log_l[shell] = np.append(self.log_l[shell], log_l, axis=0)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/nautilus/sampler.py:865, in Sampler.evaluate_likelihood(self, points)
#     863 # Evaluate the likelihood.
#     864 if self.vectorized:
# --> 865     result = self.likelihood(args)
#     866     if isinstance(result, tuple):
#     867         result = list(zip(*result))
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/fitness.py:196, in Fitness.call_wrap(self, parameters)
#     193     if len(np.array(parameters).shape) == 1:
#     194         parameters = np.array(parameters)[None, :]
# --> 196 figure_of_merit = self._call(parameters)
#     198 if self.fom_is_log_likelihood:
#     199     log_likelihood = figure_of_merit
#
#     [... skipping hidden 14 frame]
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/fitness.py:144, in Fitness.call(self, parameters)
#     127 """
#     128 A private method that calls the fitness function with the given parameters and additional keyword arguments.
#     129 This method is intended for internal use only.
#    (...)    141 The figure of merit returned to the non-linear search, which is either the log likelihood or log posterior.
#     142 """
#     143 # Get instance from model
# --> 144 instance = self.model.instance_from_vector(vector=parameters)
#     146 # Evaluate log likelihood (must be side-effect free and exception-free)
#     147 log_likelihood = self.analysis.log_likelihood_function(instance=instance)
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:780, in AbstractPriorModel.instance_from_vector(self, vector, ignore_assertions)
#     769     raise AssertionError(
#     770         f"Vector length {len(vector)} != prior count {self.prior_count}"
#     771     )
#     772 arguments = dict(
#     773     map(
#     774         lambda prior_tuple, physical_unit: (prior_tuple.prior, physical_unit),
#    (...)    777     )
#     778 )
# --> 780 return self.instance_for_arguments(
#     781     arguments,
#     782     ignore_assertions=ignore_assertions,
#     783 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/collection.py:231, in Collection._instance_for_arguments(self, arguments, ignore_assertions)
#     229     continue
#     230 if isinstance(value, AbstractPriorModel):
# --> 231     value = value.instance_for_arguments(
#     232         arguments,
#     233         ignore_assertions=ignore_assertions,
#     234     )
#     235 elif isinstance(value, Prior):
#     236     value = arguments[value]
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/collection.py:231, in Collection._instance_for_arguments(self, arguments, ignore_assertions)
#     229     continue
#     230 if isinstance(value, AbstractPriorModel):
# --> 231     value = value.instance_for_arguments(
#     232         arguments,
#     233         ignore_assertions=ignore_assertions,
#     234     )
#     235 elif isinstance(value, Prior):
#     236     value = arguments[value]
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/prior_model.py:494, in Model._instance_for_arguments(self, arguments, ignore_assertions)
#     490 for prior_model_tuple in self.direct_prior_model_tuples:
#     491     prior_model = prior_model_tuple.prior_model
#     492     model_arguments[
#     493         prior_model_tuple.name
# --> 494     ] = prior_model.instance_for_arguments(
#     495         arguments,
#     496         ignore_assertions=ignore_assertions,
#     497     )
#     499 prior_arguments = dict()
#     501 for name, prior in self.direct_prior_tuples:
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/prior_model.py:494, in Model._instance_for_arguments(self, arguments, ignore_assertions)
#     490 for prior_model_tuple in self.direct_prior_model_tuples:
#     491     prior_model = prior_model_tuple.prior_model
#     492     model_arguments[
#     493         prior_model_tuple.name
# --> 494     ] = prior_model.instance_for_arguments(
#     495         arguments,
#     496         ignore_assertions=ignore_assertions,
#     497     )
#     499 prior_arguments = dict()
#     501 for name, prior in self.direct_prior_tuples:
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/abstract.py:1340, in AbstractPriorModel.instance_for_arguments(self, arguments, ignore_assertions)
#    1335 if not (
#    1336     conf.instance["general"]["test"]["exception_override"] or ignore_assertions
#    1337 ):
#    1338     self.check_assertions(arguments)
# -> 1340 return self._instance_for_arguments(
#    1341     arguments,
#    1342     ignore_assertions=ignore_assertions,
#    1343 )
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/mapper/prior_model/prior_model.py:526, in Model._instance_for_arguments(self, arguments, ignore_assertions)
#     524     cls(result, **constructor_arguments)
#     525 else:
# --> 526     result = self.cls(**constructor_arguments)
#     528 for key, value in self.__dict__.items():
#     529     if (
#     530         not hasattr(result, key)
#     531         and not isinstance(value, Prior)
#     532         and not key == "cls"
#     533         and not key.startswith("_")
#     534     ):
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autoarray/inversion/pixelization/mesh/rectangular.py:46, in Rectangular.__init__(self, shape)
#      17 def __init__(self, shape: Tuple[int, int] = (3, 3)):
#      18     """
#      19     A uniform mesh of rectangular pixels, which without interpolation are paired with a 2D grid of (y,x)
#      20     coordinates.
#    (...)     43         The 2D dimensions of the rectangular grid of pixels (total_y_pixels, total_x_pixel).
#      44     """
# ---> 46     if shape[0] <= 2 or shape[1] <= 2:
#      47         raise exc.MeshException(
#      48             "The rectangular pixelization must be at least dimensions 3x3"
#      49         )
#      51     self.shape = (int(shape[0]), int(shape[1]))
#
#     [... skipping hidden 1 frame]
#
# File /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/jax/_src/core.py:1475, in concretization_function_error.<locals>.error(self, arg)
#    1474 def error(self, arg):
# -> 1475   raise TracerBoolConversionError(arg)
#
# TracerBoolConversionError: Attempted boolean conversion of traced array with shape bool[]..
# The error occurred while tracing the function call at /opt/anaconda3/envs/autolens/lib/python3.11/site-packages/autofit/non_linear/fitness.py:126 for jit. This concrete value was not available in Python because it depends on the value of the argument parameters.
# See https://jax.readthedocs.io/en/latest/errors.html#jax.errors.TracerBoolConversionError

# %% [markdown]
# __Wrap Up__
#
# And with that, we now have a pipeline to model strong lenses using an inversion!
#
# Checkout the example pipelines in the `autolens_workspace/*/chaining` package for inversion pipelines that
# includes the lens light component.
