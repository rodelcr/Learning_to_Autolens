# %% [markdown]
# # Solutions — Module 15: Radial Arcs & Caustic Topology
#
# **This notebook is a pointer, not a solution set.** Module 15 is *pedagogy-only* — it derives radial-vs-tangential caustic topology, magnification asymptotics, the γ′ constraint from radial arcs, and the γ′–M_BH degeneracy. The numerical demonstrations are inline; there are no explicit student exercises in the main notebook.
#
# **For the practical methodology** (mock generation, fit driver, Cannon submission, posterior interpretation, kinematics break) see:
#
# 1. **`Examples/radial_arc_smbh/`** — depth-B methodology bridge with Cannon-audited STRICT-PASS results (v0.96 ship). The 8-section walkthrough `01_radial_arc_smbh.ipynb` covers:
#    - Mock geometry inspection
#    - 6-panel residual audit (Module 11 framework)
#    - Δlog_Z=+1.71 BH-not-detected result (γ′–M_BH degeneracy in numerical form)
#    - γ′ + θ_E_BH joint posterior interpretation
#    - Bridge to depth-C real-target application
#
# 2. **`Examples/radial_arc_smbh/ --part=with_kinematics`** (v0.96 driver wired, v0.97 Cannon ship) — the joint imaging + Jeans σ_v fit that breaks the degeneracy.
#
# 3. **`Modules/13_TDCOSMO_Kinematics_MSD/`** — Jeans theory the kinematic break depends on.
#
# ## If you want exercises
#
# The Module 15 main notebook ends with a numerical demonstration of the γ′–M_BH degeneracy (cell `mod15-mbh-figure`). Productive follow-ups:
#
# 1. **Re-run the caustic-topology figure** (cell `mod15-caustic-figure`) with a non-axisymmetric lens — add `ExternalShear` with γ_shear = 0.05. How does the tangential caustic open up? At what γ′ does the radial caustic survive?
# 2. **Vary θ_E_BH** in cell `mod15-mbh-figure` from 0.01″ to 0.20″. At what value does γ_eff (inner-only fit) cross 2.5? This is the imaging-only detection floor.
# 3. **Repeat exercise 2 with kinematics added** — see `Examples/radial_arc_smbh/01_radial_arc_smbh.ipynb` for the joint-fit framework and `Modules/10_Cluster_Computing/scripts/_jeans_sigma_v.py` for the Jeans solver.
#
# ## References used in Module 15
#
# - Congdon & Keeton (2018) Ch. 6 — caustic topology theory
# - Schneider, Ehlers & Falco (1992) §5 — critical curves and caustics
# - Sonnenfeld+13 — γ′ recovery on SL2S
# - Auger+10 — SLACS structural decomposition
# - Shajib et al. — first Einstein spiral
# - Ferrami et al. — DESJ0206 ApJL
